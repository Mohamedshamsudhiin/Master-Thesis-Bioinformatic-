# %%
import pandas as pd
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import roc_curve, auc
from mlxtend.plotting import plot_learning_curves
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.inspection import permutation_importance
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # General function to open the file
# input only the file_paath

# %%
def open_file(file_path):
    """
    General function to open a file and return its DataFrame.
    The function relays on pandas
    Parameters:
    file_path (str): The path to the file.

    Returns:
    pd.DataFrame: DataFrame containing the file's data.
    """
    try:
        # Use default separator '\t' for tab-separated files
        df = pd.read_csv(file_path, sep='\t')
        print(f"Successfully loaded file: {file_path}")
        return df
    except Exception as e:
        print(f"Error loading file: {file_path}. Error: {e}")
        return None

# Run the function
file_path1 = "/home/user/Desktop/2024_08_27/master-project2/all_feature_labels.txt"
df1 = open_file(file_path1)
# Out:
# Successfully loaded file: /home/user/Desktop/2024_08_27/master-project2/all_feature_labels.txt

# %%
df1
# Out:
#      Class_label_sum cell_line condition Gene_combination  \
# 0              no GI      A375       2CP       AAK1_BMP2K
# 1                lol      A375       2CP      AARS1_AARS2
# 2              no GI      A375       2CP      ABCA2_ABCA3
# 3              no GI      A375       2CP      ABCA2_ABCA7
# 4              no GI      A375       2CP      ABCA3_ABCA7
# ...              ...       ...       ...              ...
# 8714           no GI   Meljuso   2CP sel  ZSCAN30_ZSCAN31
# 8715           no GI   Meljuso   2CP sel   ZSCAN30_ZSCAN9
# 8716           no GI   Meljuso   2CP sel   ZSCAN31_ZSCAN9
# 8717           no GI   Meljuso   2CP sel    ZSWIM4_ZSWIM6
# 8718           no GI   Meljuso   2CP sel        ZXDB_ZXDC
#
#       single_gene_highist_avg_lfc  single_gene_lowest_avg_lfc  \
# 0                       -0.524813                   -0.986385
# 1                       -2.982134                   -4.557785
# 2                       -0.005448                   -0.717969
# 3                        0.141434                   -0.005448
# 4                        0.141434                   -0.717969
# ...                           ...                         ...
# 8714                     0.242981                    0.182299
# 8715                     0.642505                    0.242981
# 8716                     0.642505                    0.182299
# 8717                     0.165044                   -0.601162
# 8718                     1.468081                   -0.867277
#
#       expected_combinatorial_lfc  combinatorial_avg_lfc  \
# 0                      -1.511197              -1.323147
# 1                      -7.539920              -4.733963
# 2                      -0.723418               0.234114
# 3                       0.135985              -0.228554
# 4                      -0.576535              -0.540774
# ...                          ...                    ...
# 8714                    0.425280               0.661490
# 8715                    0.885486               0.273976
# 8716                    0.824804               0.432295
# 8717                   -0.436118              -0.324097
# 8718                    0.600803              -0.643955
#
#       Euclidean_distance_expexted_observed  \
# 0                                 0.188050
# 1                                 2.805956
# 2                                 0.957531
# 3                                 0.364539
# 4                                 0.035761
# ...                                    ...
# 8714                              0.236209
# 8715                              0.611510
# 8716                              0.392508
# 8717                              0.112021
# 8718                              1.244758
#
#       Euclidean_distance_singel_phenotype  ...  pscore  ascore  escore  \
# 0                                0.461572  ...   0.000   0.000     0.0
# 1                                1.575651  ...   0.000   0.000     0.0
# 2                                0.712521  ...   0.000   0.000     0.0
# 3                                0.146882  ...   0.000   0.000     0.0
# 4                                0.859403  ...   0.000   0.000     0.0
# ...                                   ...  ...     ...     ...     ...
# 8714                             0.060682  ...   0.000   0.000     0.0
# 8715                             0.399523  ...   0.000   0.000     0.0
# 8716                             0.460205  ...   0.000   0.000     0.0
# 8717                             0.766206  ...   0.057   0.053     0.0
# 8718                             2.335358  ...   0.000   0.000     0.0
#
#       dscore  Jaccard Index_commun_proteins  Number of Common Proteins  \
# 0       0.00                       0.333333                          5
# 1       0.00                       0.111111                          2
# 2       0.00                       0.000000                          0
# 3       0.00                       0.000000                          0
# 4       0.00                       0.000000                          0
# ...      ...                            ...                        ...
# 8714    0.00                       0.000000                          0
# 8715    0.00                       0.066667                          1
# 8716    0.00                       0.125000                          1
# 8717    0.54                       0.666667                          8
# 8718    0.00                       0.062500                          1
#
#       Class_label_exp  Class_label_dep  Class_label_corr  Class_label_neg
# 0               no GI            no GI             no GI            no GI
# 1               no GI            no GI             no GI            Mixed
# 2               no GI            no GI             no GI            no GI
# 3               no GI            no GI             no GI            no GI
# 4               no GI            no GI             no GI            no GI
# ...               ...              ...               ...              ...
# 8714            no GI            no GI             no GI            no GI
# 8715            no GI            no GI             no GI            no GI
# 8716            no GI            no GI             no GI            no GI
# 8717            no GI            no GI             no GI            no GI
# 8718            no GI            no GI             no GI            no GI
#
# [8719 rows x 40 columns]

# %% [markdown]
# # Function to filter raws only want to use in spicific classafier

# %%
def filter_rows(df, column_name_no_GI, no_GI_value, column_name_GI, GI_value):
    """
    Filters rows in the DataFrame based on two column conditions (either condition can be true).
    
    Parameters:
    df (pd.DataFrame): The DataFrame to filter.
    column_name_no_GI (str): The name of the first column to filter on (e.g., 'Class_label_neg').
    no_GI_value: The value to filter for in the first column (e.g., 'no GI').
    column_name_GI (str): The name of the second column to filter on (e.g., 'Class_label_sum').
    GI_value: The value to filter for in the second column (e.g., 'GI').

    Returns:
    pd.DataFrame: A DataFrame containing rows that match either of the conditions.
    """
    try:
        # Apply filtering conditions with OR (`|`)
        filtered_df = df[(df[column_name_no_GI] == no_GI_value) | (df[column_name_GI] == GI_value)]
        print(f"Filtered DataFrame has {filtered_df.shape[0]} rows and {filtered_df.shape[1]} columns.")
        return filtered_df
    except KeyError as e:
        print(f"Column not found: {e}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Filter rows where "Class_label_neg" is "no GI" and "Class_label_sum" is "GI"
filtered_df = filter_rows(df1, "Class_label_neg", "no GI", "Class_label_exp", "GI")

# Display filtered DataFrame
print(filtered_df)
# Out:
# Filtered DataFrame has 7367 rows and 40 columns.
#      Class_label_sum cell_line condition Gene_combination  \
# 0              no GI      A375       2CP       AAK1_BMP2K
# 2              no GI      A375       2CP      ABCA2_ABCA3
# 3              no GI      A375       2CP      ABCA2_ABCA7
# 4              no GI      A375       2CP      ABCA3_ABCA7
# 5              no GI      A375       2CP     ABCB10_ABCB8
# ...              ...       ...       ...              ...
# 8714           no GI   Meljuso   2CP sel  ZSCAN30_ZSCAN31
# 8715           no GI   Meljuso   2CP sel   ZSCAN30_ZSCAN9
# 8716           no GI   Meljuso   2CP sel   ZSCAN31_ZSCAN9
# 8717           no GI   Meljuso   2CP sel    ZSWIM4_ZSWIM6
# 8718           no GI   Meljuso   2CP sel        ZXDB_ZXDC
#
#       single_gene_highist_avg_lfc  single_gene_lowest_avg_lfc  \
# 0                       -0.524813                   -0.986385
# 2                       -0.005448                   -0.717969
# 3                        0.141434                   -0.005448
# 4                        0.141434                   -0.717969
# 5                        0.480443                   -2.020990
# ...                           ...                         ...
# 8714                     0.242981                    0.182299
# 8715                     0.642505                    0.242981
# 8716                     0.642505                    0.182299
# 8717                     0.165044                   -0.601162
# 8718                     1.468081                   -0.867277
#
#       expected_combinatorial_lfc  combinatorial_avg_lfc  \
# 0                      -1.511197              -1.323147
# 2                      -0.723418               0.234114
# 3                       0.135985              -0.228554
# 4                      -0.576535              -0.540774
# 5                      -1.540546              -0.952027
# ...                          ...                    ...
# 8714                    0.425280               0.661490
# 8715                    0.885486               0.273976
# 8716                    0.824804               0.432295
# 8717                   -0.436118              -0.324097
# 8718                    0.600803              -0.643955
#
#       Euclidean_distance_expexted_observed  \
# 0                                 0.188050
# 2                                 0.957531
# 3                                 0.364539
# 4                                 0.035761
# 5                                 0.588519
# ...                                    ...
# 8714                              0.236209
# 8715                              0.611510
# 8716                              0.392508
# 8717                              0.112021
# 8718                              1.244758
#
#       Euclidean_distance_singel_phenotype  ...  pscore  ascore  escore  \
# 0                                0.461572  ...   0.000   0.000     0.0
# 2                                0.712521  ...   0.000   0.000     0.0
# 3                                0.146882  ...   0.000   0.000     0.0
# 4                                0.859403  ...   0.000   0.000     0.0
# 5                                2.501433  ...   0.000   0.000     0.0
# ...                                   ...  ...     ...     ...     ...
# 8714                             0.060682  ...   0.000   0.000     0.0
# 8715                             0.399523  ...   0.000   0.000     0.0
# 8716                             0.460205  ...   0.000   0.000     0.0
# 8717                             0.766206  ...   0.057   0.053     0.0
# 8718                             2.335358  ...   0.000   0.000     0.0
#
#       dscore  Jaccard Index_commun_proteins  Number of Common Proteins  \
# 0       0.00                       0.333333                          5
# 2       0.00                       0.000000                          0
# 3       0.00                       0.000000                          0
# 4       0.00                       0.000000                          0
# 5       0.00                       0.111111                          2
# ...      ...                            ...                        ...
# 8714    0.00                       0.000000                          0
# 8715    0.00                       0.066667                          1
# 8716    0.00                       0.125000                          1
# 8717    0.54                       0.666667                          8
# 8718    0.00                       0.062500                          1
#
#       Class_label_exp  Class_label_dep  Class_label_corr  Class_label_neg
# 0               no GI            no GI             no GI            no GI
# 2               no GI            no GI             no GI            no GI
# 3               no GI            no GI             no GI            no GI
# 4               no GI            no GI             no GI            no GI
# 5               no GI            no GI             no GI            no GI
# ...               ...              ...               ...              ...
# 8714            no GI            no GI             no GI            no GI
# 8715            no GI            no GI             no GI            no GI
# 8716            no GI            no GI             no GI            no GI
# 8717            no GI            no GI             no GI            no GI
# 8718            no GI            no GI             no GI            no GI
#
# [7367 rows x 40 columns]

# %% [markdown]
# # Function to create a temporary label column based on the desired condition

# %%
import pandas as pd
import matplotlib.pyplot as plt

def assign_and_visualize_class_label(df, column_name_no_GI, no_GI_value, column_name_GI, GI_value):
    """
    Adds a new column 'temp_class_label' based on two conditions and visualizes the class distribution.
    The function rely on pandas and matplotlib pyplot function
    Parameters:
    df (pd.DataFrame): The DataFrame to modify.
    column_name_no_GI (str): The first column to filter on (e.g., 'Class_label_neg').
    no_GI_value: The value to assign 'no GI' if it matches in the first column.
    column_name_GI (str): The second column to filter on (e.g., 'Class_label_sum').
    GI_value: The value to assign 'GI' if it matches in the second column.

    Returns:
    pd.DataFrame: The DataFrame with the new 'temp_class_label' column.
    """
    try:
        # Create the 'temp_class_label' column based on the conditions
        df['temp_class_label'] = df.apply(
            lambda row: 'GI' if row[column_name_GI] == GI_value else 
                        ('no GI' if row[column_name_no_GI] == no_GI_value else 'Excluded'),
            axis=1
        )

        print(f"New column 'temp_class_label' has been added to the DataFrame.")
        
        # Generate dynamic title based on input column names and values
        plot_title = f"{column_name_no_GI}: {no_GI_value}, {column_name_GI}: {GI_value}"

        # Visualize the distribution of 'temp_class_label' with a histogram
        plt.figure(figsize=(8, 6))
        df['temp_class_label'].value_counts().plot(kind='bar', color=['skyblue', 'orange'], alpha=0.7)
        
        # Set plot title and labels
        plt.title(plot_title, fontsize=14)
        plt.xlabel('Class Labels', fontsize=12)
        plt.ylabel('Frequency', fontsize=12)
        plt.xticks(rotation=0)
        plt.tight_layout()

        # Display the plot
        plt.show()

        return df

    except KeyError as e:
        print(f"Column not found: {e}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None
    

 # Add the 'temp_class_label' based on conditions
df_label = assign_and_visualize_class_label(filtered_df, "Class_label_neg", "no GI", "Class_label_exp", "GI")
df_label
# Out:
# New column 'temp_class_label' has been added to the DataFrame.
# /tmp/ipykernel_2514/3148194539.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temp_class_label'] = df.apply(
#      Class_label_sum cell_line condition Gene_combination  \
# 0              no GI      A375       2CP       AAK1_BMP2K
# 2              no GI      A375       2CP      ABCA2_ABCA3
# 3              no GI      A375       2CP      ABCA2_ABCA7
# 4              no GI      A375       2CP      ABCA3_ABCA7
# 5              no GI      A375       2CP     ABCB10_ABCB8
# ...              ...       ...       ...              ...
# 8714           no GI   Meljuso   2CP sel  ZSCAN30_ZSCAN31
# 8715           no GI   Meljuso   2CP sel   ZSCAN30_ZSCAN9
# 8716           no GI   Meljuso   2CP sel   ZSCAN31_ZSCAN9
# 8717           no GI   Meljuso   2CP sel    ZSWIM4_ZSWIM6
# 8718           no GI   Meljuso   2CP sel        ZXDB_ZXDC
#
#       single_gene_highist_avg_lfc  single_gene_lowest_avg_lfc  \
# 0                       -0.524813                   -0.986385
# 2                       -0.005448                   -0.717969
# 3                        0.141434                   -0.005448
# 4                        0.141434                   -0.717969
# 5                        0.480443                   -2.020990
# ...                           ...                         ...
# 8714                     0.242981                    0.182299
# 8715                     0.642505                    0.242981
# 8716                     0.642505                    0.182299
# 8717                     0.165044                   -0.601162
# 8718                     1.468081                   -0.867277
#
#       expected_combinatorial_lfc  combinatorial_avg_lfc  \
# 0                      -1.511197              -1.323147
# 2                      -0.723418               0.234114
# 3                       0.135985              -0.228554
# 4                      -0.576535              -0.540774
# 5                      -1.540546              -0.952027
# ...                          ...                    ...
# 8714                    0.425280               0.661490
# 8715                    0.885486               0.273976
# 8716                    0.824804               0.432295
# 8717                   -0.436118              -0.324097
# 8718                    0.600803              -0.643955
#
#       Euclidean_distance_expexted_observed  \
# 0                                 0.188050
# 2                                 0.957531
# 3                                 0.364539
# 4                                 0.035761
# 5                                 0.588519
# ...                                    ...
# 8714                              0.236209
# 8715                              0.611510
# 8716                              0.392508
# 8717                              0.112021
# 8718                              1.244758
#
#       Euclidean_distance_singel_phenotype  ...  ascore  escore  dscore  \
# 0                                0.461572  ...   0.000     0.0    0.00
# 2                                0.712521  ...   0.000     0.0    0.00
# 3                                0.146882  ...   0.000     0.0    0.00
# 4                                0.859403  ...   0.000     0.0    0.00
# 5                                2.501433  ...   0.000     0.0    0.00
# ...                                   ...  ...     ...     ...     ...
# 8714                             0.060682  ...   0.000     0.0    0.00
# 8715                             0.399523  ...   0.000     0.0    0.00
# 8716                             0.460205  ...   0.000     0.0    0.00
# 8717                             0.766206  ...   0.053     0.0    0.54
# 8718                             2.335358  ...   0.000     0.0    0.00
#
#       Jaccard Index_commun_proteins  Number of Common Proteins  \
# 0                          0.333333                          5
# 2                          0.000000                          0
# 3                          0.000000                          0
# 4                          0.000000                          0
# 5                          0.111111                          2
# ...                             ...                        ...
# 8714                       0.000000                          0
# 8715                       0.066667                          1
# 8716                       0.125000                          1
# 8717                       0.666667                          8
# 8718                       0.062500                          1
#
#       Class_label_exp  Class_label_dep  Class_label_corr  Class_label_neg  \
# 0               no GI            no GI             no GI            no GI
# 2               no GI            no GI             no GI            no GI
# 3               no GI            no GI             no GI            no GI
# 4               no GI            no GI             no GI            no GI
# 5               no GI            no GI             no GI            no GI
# ...               ...              ...               ...              ...
# 8714            no GI            no GI             no GI            no GI
# 8715            no GI            no GI             no GI            no GI
# 8716            no GI            no GI             no GI            no GI
# 8717            no GI            no GI             no GI            no GI
# 8718            no GI            no GI             no GI            no GI
#
#       temp_class_label
# 0                no GI
# 2                no GI
# 3                no GI
# 4                no GI
# 5                no GI
# ...                ...
# 8714             no GI
# 8715             no GI
# 8716             no GI
# 8717             no GI
# 8718             no GI
#
# [7367 rows x 41 columns]

# %% [markdown]
# # Chech if there are missing values and replace them with 0
#
# The function prints out the missing values before replacing them and returns the DataFrame with missing values replaced by 0.

# %%
def check_and_replace_missing_values(df):
    # Check if there are missing values in the DataFrame
    missing_values = df.isnull().sum()
    print("Missing values:")
    print(missing_values)
    
    # Replace missing values with 0
    df_filled = df.fillna(0)
    
    # Return the updated DataFrame
    return df_filled

# Call the function
filtered_df = check_and_replace_missing_values(filtered_df)
filtered_df
# Out:
# Missing values:
# Class_label_sum                           0
# cell_line                                 0
# condition                                 0
# Gene_combination                          0
# single_gene_highist_avg_lfc               0
# single_gene_lowest_avg_lfc                0
# expected_combinatorial_lfc                0
# combinatorial_avg_lfc                     0
# Euclidean_distance_expexted_observed      0
# Euclidean_distance_singel_phenotype       0
# highist_expression                        0
# lowest_expression                         0
# Euclidean_distance_expresstion            0
# expre_Correlation                         0
# highist_dep                              16
# lowest_dep                               16
# Euclidean_distance_dep                  205
# dep_Correlation                          14
# highist_damage_mutation                 853
# lowest_damage_mutation                  853
# Euclidean_distance_dm                   853
# Jaccard BP Similarity                     0
# Jaccard MF Similarity                     0
# Jaccard CC Similarity                     0
# Average Wang BP Similarity                0
# Average Wang MF Similarity                0
# Average Wang CC Similarity                0
# score                                     0
# nscore                                    0
# fscore                                    0
# pscore                                    0
# ascore                                    0
# escore                                    0
# dscore                                    0
# Jaccard Index_commun_proteins             0
# Number of Common Proteins                 0
# Class_label_exp                           0
# Class_label_dep                          14
# Class_label_corr                          0
# Class_label_neg                           0
# temp_class_label                          0
# dtype: int64
#      Class_label_sum cell_line condition Gene_combination  \
# 0              no GI      A375       2CP       AAK1_BMP2K
# 2              no GI      A375       2CP      ABCA2_ABCA3
# 3              no GI      A375       2CP      ABCA2_ABCA7
# 4              no GI      A375       2CP      ABCA3_ABCA7
# 5              no GI      A375       2CP     ABCB10_ABCB8
# ...              ...       ...       ...              ...
# 8714           no GI   Meljuso   2CP sel  ZSCAN30_ZSCAN31
# 8715           no GI   Meljuso   2CP sel   ZSCAN30_ZSCAN9
# 8716           no GI   Meljuso   2CP sel   ZSCAN31_ZSCAN9
# 8717           no GI   Meljuso   2CP sel    ZSWIM4_ZSWIM6
# 8718           no GI   Meljuso   2CP sel        ZXDB_ZXDC
#
#       single_gene_highist_avg_lfc  single_gene_lowest_avg_lfc  \
# 0                       -0.524813                   -0.986385
# 2                       -0.005448                   -0.717969
# 3                        0.141434                   -0.005448
# 4                        0.141434                   -0.717969
# 5                        0.480443                   -2.020990
# ...                           ...                         ...
# 8714                     0.242981                    0.182299
# 8715                     0.642505                    0.242981
# 8716                     0.642505                    0.182299
# 8717                     0.165044                   -0.601162
# 8718                     1.468081                   -0.867277
#
#       expected_combinatorial_lfc  combinatorial_avg_lfc  \
# 0                      -1.511197              -1.323147
# 2                      -0.723418               0.234114
# 3                       0.135985              -0.228554
# 4                      -0.576535              -0.540774
# 5                      -1.540546              -0.952027
# ...                          ...                    ...
# 8714                    0.425280               0.661490
# 8715                    0.885486               0.273976
# 8716                    0.824804               0.432295
# 8717                   -0.436118              -0.324097
# 8718                    0.600803              -0.643955
#
#       Euclidean_distance_expexted_observed  \
# 0                                 0.188050
# 2                                 0.957531
# 3                                 0.364539
# 4                                 0.035761
# 5                                 0.588519
# ...                                    ...
# 8714                              0.236209
# 8715                              0.611510
# 8716                              0.392508
# 8717                              0.112021
# 8718                              1.244758
#
#       Euclidean_distance_singel_phenotype  ...  ascore  escore  dscore  \
# 0                                0.461572  ...   0.000     0.0    0.00
# 2                                0.712521  ...   0.000     0.0    0.00
# 3                                0.146882  ...   0.000     0.0    0.00
# 4                                0.859403  ...   0.000     0.0    0.00
# 5                                2.501433  ...   0.000     0.0    0.00
# ...                                   ...  ...     ...     ...     ...
# 8714                             0.060682  ...   0.000     0.0    0.00
# 8715                             0.399523  ...   0.000     0.0    0.00
# 8716                             0.460205  ...   0.000     0.0    0.00
# 8717                             0.766206  ...   0.053     0.0    0.54
# 8718                             2.335358  ...   0.000     0.0    0.00
#
#       Jaccard Index_commun_proteins  Number of Common Proteins  \
# 0                          0.333333                          5
# 2                          0.000000                          0
# 3                          0.000000                          0
# 4                          0.000000                          0
# 5                          0.111111                          2
# ...                             ...                        ...
# 8714                       0.000000                          0
# 8715                       0.066667                          1
# 8716                       0.125000                          1
# 8717                       0.666667                          8
# 8718                       0.062500                          1
#
#       Class_label_exp  Class_label_dep  Class_label_corr  Class_label_neg  \
# 0               no GI            no GI             no GI            no GI
# 2               no GI            no GI             no GI            no GI
# 3               no GI            no GI             no GI            no GI
# 4               no GI            no GI             no GI            no GI
# 5               no GI            no GI             no GI            no GI
# ...               ...              ...               ...              ...
# 8714            no GI            no GI             no GI            no GI
# 8715            no GI            no GI             no GI            no GI
# 8716            no GI            no GI             no GI            no GI
# 8717            no GI            no GI             no GI            no GI
# 8718            no GI            no GI             no GI            no GI
#
#       temp_class_label
# 0                no GI
# 2                no GI
# 3                no GI
# 4                no GI
# 5                no GI
# ...                ...
# 8714             no GI
# 8715             no GI
# 8716             no GI
# 8717             no GI
# 8718             no GI
#
# [7367 rows x 41 columns]

# %% [markdown]
# # Numeric columns

# %%
# Get numeric columns (either int or float)
numeric_columns = filtered_df.select_dtypes(include=['number']).columns

# Display the numeric columns
print(f"Numeric columns: {numeric_columns}")
# Out:
# Numeric columns: Index(['single_gene_highist_avg_lfc', 'single_gene_lowest_avg_lfc',
#        'expected_combinatorial_lfc', 'combinatorial_avg_lfc',
#        'Euclidean_distance_expexted_observed',
#        'Euclidean_distance_singel_phenotype', 'highist_expression',
#        'lowest_expression', 'Euclidean_distance_expresstion',
#        'expre_Correlation', 'highist_dep', 'lowest_dep',
#        'Euclidean_distance_dep', 'dep_Correlation', 'highist_damage_mutation',
#        'lowest_damage_mutation', 'Euclidean_distance_dm',
#        'Jaccard BP Similarity', 'Jaccard MF Similarity',
#        'Jaccard CC Similarity', 'Average Wang BP Similarity',
#        'Average Wang MF Similarity', 'Average Wang CC Similarity', 'score',
#        'nscore', 'fscore', 'pscore', 'ascore', 'escore', 'dscore',
#        'Jaccard Index_commun_proteins', 'Number of Common Proteins'],
#       dtype='object')

# %% [markdown]
# # General function to split the data in two set training and test set with ensuring the reprecentaion of both class label GI and no GI
#
# The stratification ensures that the proportions of each class in temp_class_label are preserved in both the training and testing sets.
# Map the label 'GI' to 1 and 'no GI' to 0 because LabelEncoder will assign values based on the default order, which may vary. The LabelEncoder helps convert categorical values to numeric values, which is important for machine learning models as they require numeric inputs

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd

def split_train_test(df, target_col, exclude_cols, test_size=0.2, random_state=0):
    """
    Splits the data into training and test sets  based on class distribution.
     The function need train_test_split from sklearn.model_selection 
     LabelEncoder function from from sklearn.preprocessing 
     pandass
    Parameters:
        df (pd.DataFrame): The input DataFrame.
        target_col (str): The column name of the target variable (y).
        exclude_cols (list): List of column names to exclude from the features (X).
        test_size (float): Proportion of the dataset to be used as test (default: 0.2).
        random_state (int): Random state for reproducibility (default: 0).
        
    Returns:
        X_train, X_test: Feature sets for training and testing.
        y_train, y_test: Target sets for training and testing.
        label_encoder: The label encoder used for target encoding.
    """
    # Separate features and target
    X = df.drop(columns=exclude_cols)
    y = df[target_col]
    
    # Manually map 'GI' to 1 and 'no GI' to 0 using .map() 
    y = y.map({'GI': 1, 'no GI': 0})
    
    # Ensure type is explicitly int (important for machine learning models)
    y = y.astype(int)
    
    # Encode the target labels using LabelEncoder 
    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)
    
    # Split data into training and test sets with stratification
    X_train, X_test, y_train, y_test = train_test_split(
        X, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded
    )
    
    # Print label distributions to confirm stratification
    print("Original label distribution:", pd.Series(y).value_counts().to_dict())
    print("Training label distribution:", pd.Series(y_train).value_counts().to_dict())
    print("Testing label distribution:", pd.Series(y_test).value_counts().to_dict())
    
    # Print encoded class mapping
    print("Encoded classes:", label_encoder.classes_)
    
    return X_train, X_test, y_train, y_test, label_encoder

# Call the function with your DataFrame
X_train, X_test, y_train, y_test, label_encoder = split_train_test(
    df=filtered_df,
    target_col='temp_class_label',
    exclude_cols=['Class_label_sum', 'cell_line', 'condition', 'Gene_combination', 'Class_label_exp','Class_label_dep','Class_label_corr','Class_label_neg','temp_class_label','escore','score'],
    test_size=0.2,
    random_state=0
)

# Get the column names of X_train
column_names = X_train.columns.tolist()
print(column_names)
# Out:
# Original label distribution: {0: 5690, 1: 1677}
# Training label distribution: {0: 4552, 1: 1341}
# Testing label distribution: {0: 1138, 1: 336}
# Encoded classes: [0 1]
# ['single_gene_highist_avg_lfc', 'single_gene_lowest_avg_lfc', 'expected_combinatorial_lfc', 'combinatorial_avg_lfc', 'Euclidean_distance_expexted_observed', 'Euclidean_distance_singel_phenotype', 'highist_expression', 'lowest_expression', 'Euclidean_distance_expresstion', 'expre_Correlation', 'highist_dep', 'lowest_dep', 'Euclidean_distance_dep', 'dep_Correlation', 'highist_damage_mutation', 'lowest_damage_mutation', 'Euclidean_distance_dm', 'Jaccard BP Similarity', 'Jaccard MF Similarity', 'Jaccard CC Similarity', 'Average Wang BP Similarity', 'Average Wang MF Similarity', 'Average Wang CC Similarity', 'nscore', 'fscore', 'pscore', 'ascore', 'dscore', 'Jaccard Index_commun_proteins', 'Number of Common Proteins']

# %% [markdown]
# # Custom function for comfustion matrix for multiple classifier.

# %%
def plot_custom_confusion_matrices_multi_classifiers(classifiers, X_train, y_train, X_test, y_test, class_order=[1, 0], display_labels=['GI', 'No GI']):
    """
    Plots confusion matrices for multiple classifiers for the test set.
    The function relays on : 
    from sklearn.dummy import DummyClassifier
    from sklearn.linear_model import LogisticRegression
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.svm import SVC
    from sklearn.neighbors import KNeighborsClassifier
   from sklearn.naive_bayes import GaussianNB
   from sklearn.tree import DecisionTreeClassifier
    from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt
    
    Parameters:
    - classifiers: A dictionary of classifier names and classifier objects (e.g., {'Logistic Regression': LogisticRegression()})
    - X_train: Training data features
    - y_train: Training data labels
    - X_test: Test data features
    - y_test: Test data labels
    - class_order: List of class indices in desired order (default [1, 0])
    - display_labels: List of display labels in desired order (default ['GI', 'No GI'])

    Returns:
    - Plots confusion matrices for each classifier on the test set.
    """
    from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
    import matplotlib.pyplot as plt

    for clf_name, clf in classifiers.items():
        print(f"Training {clf_name}...")

        # Train classifier on the training data
        clf.fit(X_train, y_train)
        
        # Make predictions on the test set
        y_test_pred = clf.predict(X_test)
        
        # Compute confusion matrix
        cm_test = confusion_matrix(y_test, y_test_pred)
        
        # Reorder confusion matrix based on class_order
        cm_test_reordered = cm_test[class_order][:, class_order]
        
        # Create ConfusionMatrixDisplay for the test set
        disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test_reordered, display_labels=display_labels)
        
        # Create a figure for each classifier
        fig, ax = plt.subplots(figsize=(6, 6))
        
        # Plot test confusion matrix
        disp_test.plot(cmap=plt.cm.Blues, values_format='d', ax=ax)
        ax.set_title(f'{clf_name}: Test Set Confusion Matrix')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Call the function above and evaluate diffrent classafier with the defult
# ## Logistic Regression:
# itt models the probability that a given input belongs to a particular class using the logistic function.
#
# ## Random Forest:
# that builds multiple decision trees during training and outputs the class that is the mode of the classes of the individual trees. It is robust to overfitting and can handle large datasets efficiently.
#
# ## Support Vector Machine (SVM):
# powerful classifier that finds the optimal hyperplane to separate data points of different classes. It works well for both linear and non-linear classification tasks using kernel functions.
#
# ## K-Nearest Neighbors (KNN):
#
#  A simple, instance-based learning algorithm that classifies a new data point based on the majority class of its nearest neighbors (K). It's useful for small datasets but can be computationally expensive with large datasets.

# %%
# Define classifiers
classifiers = {
    'DummyClassifier' :DummyClassifier(),
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(random_state=42),
    'SVM': SVC(probability=True, random_state=42),  
    'KNN': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB(),
    
}
# Call the function with  training,  and test sets
plot_custom_confusion_matrices_multi_classifiers(
    classifiers, 
    X_train, y_train, 
    X_test, y_test, 
    class_order=[1, 0],
    display_labels=['GI', 'No GI']  
)
# Out:
# Training DummyClassifier...
# Training Logistic Regression...
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training Random Forest...
# Training SVM...
# Training KNN...
# Training Naive Bayes...

# %% [markdown]
# # General function to plot diffrent matrixses

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

def fit_and_evaluate_classifiers(classifiers, X_train, y_train, X_test, y_test, group=1):
    """
    Fit multiple classifiers, calculate performance metrics, and return a results table.
    This function relays on :
    from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score

    Parameters:
    - classifiers: Dictionary of classifier names and classifier objects (e.g., {'Logistic Regression': LogisticRegression()}).
    - X_train: Training feature set.
    - y_train: Training labels.
    - X_test: Test feature set.
    - y_test: Test labels.
    - group: The class label considered as the positive class (default is 1).

    Returns:
    - Pandas DataFrame with performance metrics (AUC, Accuracy, Precision, Recall, F1-score) for each classifier.
    """
    # Ensure that we have training and testing data
    if any(data is None for data in [X_train, y_train, X_test, y_test]):
        raise ValueError("Training and testing data must be provided.")

    # Initialize a list to store the results
    results = []

    for clf_name, clf in classifiers.items():
        print(f"Training {clf_name}...")
        
        # Fit the classifier on the training data
        clf.fit(X_train, y_train)

        # Check if the classifier supports predict_proba
        if hasattr(clf, 'predict_proba'):
            y_scores = clf.predict_proba(X_test)[:, group]
            auc_value = roc_auc_score(y_test, y_scores)
        else:
            print(f"{clf_name} does not support predict_proba, skipping AUC calculation.")
            auc_value = None

        # Get predicted labels
        y_pred = clf.predict(X_test)

        # Calculate performance metrics
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, pos_label=group, zero_division=0)
        recall = recall_score(y_test, y_pred, pos_label=group)
        f1 = f1_score(y_test, y_pred, pos_label=group)

        # Append results
        results.append({
            'Classifier': clf_name,
            'AUC': auc_value,
            'Accuracy': accuracy,
            'Precision': precision,
            'Recall': recall,
            'F1-Score': f1
        })

    # Convert results to a DataFrame
    results_df = pd.DataFrame(results)

    # Display the results
    print("\nPerformance Metrics:")
    print(results_df)


     # Visualize the results as dots
    melted_df = results_df.melt(id_vars=['Classifier'], 
                                value_vars=['AUC', 'Accuracy', 'Precision', 'Recall', 'F1-Score'], 
                                var_name='Metric', 
                                value_name='Value')


    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=melted_df, x='Metric', y='Value', hue='Classifier', style='Classifier', s=100, palette='tab10')
    plt.title('Classifier Performance Metrics')
    plt.ylabel('Metric Value')
    plt.xlabel('Metric')
    plt.ylim(0, 1.1)  
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()



  

    return results_df

# %% [markdown]
# # Call the function based on the clasaffaier above to extract diffrent socres

# %%
classifiers = {
    'DummyClassifier' :DummyClassifier(),
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(random_state=42),
    'SVM': SVC(probability=True, random_state=42),  
    'KNN': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB(),
    
}
results_df = fit_and_evaluate_classifiers(classifiers, X_train, y_train, X_test, y_test, group=1)
# Out:
# Training DummyClassifier...
# Training Logistic Regression...
# Training Random Forest...
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training SVM...
# Training KNN...
# Training Naive Bayes...
#
# Performance Metrics:
#             Classifier       AUC  Accuracy  Precision    Recall  F1-Score
# 0      DummyClassifier  0.500000  0.772049   0.000000  0.000000  0.000000
# 1  Logistic Regression  0.820790  0.792402   0.580645  0.321429  0.413793
# 2        Random Forest  0.933312  0.889417   0.826415  0.651786  0.728785
# 3                  SVM  0.814851  0.799864   0.649635  0.264881  0.376321
# 4                  KNN  0.773119  0.786296   0.552764  0.327381  0.411215
# 5          Naive Bayes  0.803161  0.780190   0.515464  0.595238  0.552486

# %%
results_df.to_csv('classifier_performance_metrics.csv', index=False)

# %% [markdown]
# # Write the confution matrix to axel

# %%
# Export to Excel with styling
with pd.ExcelWriter('classifier_performance_metrics.xlsx', engine='xlsxwriter') as writer:
    # Write DataFrame to Excel
    results_df.to_excel(writer, sheet_name='Metrics', index=False)

    # Access the workbook and the sheet
    workbook = writer.book
    worksheet = writer.sheets['Metrics']

    # Apply header formatting
    header_format = workbook.add_format({'bold': True, 'bg_color': '#D3D3D3', 'border': 1, 'align': 'center'})
    for col_num, value in enumerate(results_df.columns.values):
        worksheet.write(0, col_num, value, header_format)

    # Apply cell formatting
    cell_format = workbook.add_format({'border': 1, 'align': 'center'})
    worksheet.set_column('A:F', 18, cell_format)

    # Adjust column widths based on content length
    for col_num, col_name in enumerate(results_df.columns):
        max_length = max(results_df[col_name].astype(str).map(len).max(), len(col_name)) + 2
        worksheet.set_column(col_num, col_num, max_length)

# %% [markdown]
# # General function to plot Roc curve

# %%
def fit_and_plot_roc_curve_multi_classifiers(classifiers, X_train, y_train, X_test, y_test, group=1):
    """
    Function to fit multiple classifiers, plot ROC curves, and calculate AUC.
    THis function relays on:
    from sklearn.metrics import roc_curve, auc

    Parameters:
    - classifiers: Dictionary of classifier names and instances.
    - X_train: Training feature set.
    - y_train: Training labels.
    - X_test: Test feature set.
    - y_test: True labels for the test set.
    - group: The class label considered as the positive class for the ROC curve (default is 1,means GI group).
    
    Returns:
    - Plots ROC curves and AUC for each classifier.
    """
    plt.figure(figsize=(10, 8))

    for clf_name, clf in classifiers.items():
        # Fit the classifier
        clf.fit(X_train, y_train)
        
        # Ensure classifier has `predict_proba` method
        if hasattr(clf, 'predict_proba'):
            # Get the probability for the specified positive class
            y_scores = clf.predict_proba(X_test)[:, group]
        else:
            print(f"{clf_name} does not support predict_proba.")
            continue
        
        # Compute ROC curve, using 'group' as the positive class
        fpr, tpr, _ = roc_curve(y_test, y_scores, pos_label=group)
        
        # Calculate AUC
        roc_auc = auc(fpr, tpr)
        
        # Plot the ROC curve
        plt.plot(fpr, tpr, label=f'{clf_name} (AUC = {roc_auc:.2f})')

    # Plot the random guess line
    plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('ROC Curve Comparison')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Call ROC curve function

# %%
# Call the function to fit classifiers and plot ROC curves
fit_and_plot_roc_curve_multi_classifiers(classifiers, X_train, y_train, X_test, y_test)
# Out:
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Genral function for plotting learnings curve for multi classafier

# %%
def plot_learning_curves_multi_classifiers(classifiers, X_train, y_train, X_test, y_test):
    """
    Plots learning curves for multiple classifiers.
    from mlxtend.plotting import plot_learning_curves
    
    Parameters:
    - classifiers: A dictionary of classifier names and classifier objects (e.g., {'Logistic Regression': LogisticRegression()})
    - X_train: Training data features
    - y_train: Training data labels
    - X_test: Test data features
    - y_test: Test data labels
    
    Returns:
    - Plots learning curves for each classifier
    """
    for clf_name, clf in classifiers.items():
        print(f"Plotting learning curves for {clf_name}...")

        # Plot learning curves
        plt.figure(figsize=(10, 6))  
        plot_learning_curves(X_train, y_train, X_test, y_test, clf)
        
        # Set plot title
        plt.title(f'Learning Curves for {clf_name}')
        
        plt.show()

# %% [markdown]
# # Call the learnings curve

# %%
# Call the function to plot learning curves for each classifier
plot_learning_curves_multi_classifiers(
    classifiers, 
    X_train, y_train, 
    X_test, y_test)
# Out:
# Plotting learning curves for DummyClassifier...
# Plotting learning curves for Logistic Regression...
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Plotting learning curves for Random Forest...
# Plotting learning curves for SVM...
# Plotting learning curves for KNN...
# Plotting learning curves for Naive Bayes...
# Plotting learning curves for Decision Tree...

# %% [markdown]
# # Function to split the data to be sure that biologigal replicates across cell lines wil  be only in one set (training or test set)
# This done to avoid the biased of the result prediction

# %%
def split_train_test(df, target_col, exclude_cols, group_by_cols, test_size=0.2, random_state=0):
    """
    Splits the data into training and test sets:
    - Ensures all samples with the same group (e.g., same Gene_combination) are in the same set.
    - Stratifies by target column to balance the classes in train and test.
    
    Parameters:
        df (pd.DataFrame): The input DataFrame.
        target_col (str): The column name of the target variable (y).
        exclude_cols (list): List of column names to exclude from features (X).
        group_by_cols (list): List of column names to group the samples.
        test_size (float): Proportion of the dataset to be used as test (default: 0.2).
        random_state (int): Random state for reproducibility (default: 0).
        
    Returns:
        X_train, X_test: Feature sets for training and testing.
        y_train, y_test: Target sets for training and testing.
    """
    # Encode the target labels (e.g., 'GI' -> 1, 'no GI' -> 0)
    df[target_col] = df[target_col].map({'GI': 1, 'no GI': 0})
    
    # Ensure type is explicitly int for the target variable
    df[target_col] = df[target_col].astype(int)
    
    # Create a unique group_id based on the group_by_cols (Gene_combination)
    df['group_id'] = df[group_by_cols].astype(str).agg('_'.join, axis=1)
    
    # Stratify based on the target variable across group_ids (to balance classes)
    group_df = df[['group_id', target_col]].drop_duplicates()
    
    # Split the group_ids into training and testing sets with stratification based on target_col
    group_train, group_test = train_test_split(
        group_df['group_id'], 
        test_size=test_size, 
        random_state=random_state, 
        stratify=group_df[target_col]  # Stratification to balance target variable (GI/no GI)
    )
    
    # Filter rows in df based on the group_id for train and test
    train_indices = df[df['group_id'].isin(group_train)].index
    test_indices = df[df['group_id'].isin(group_test)].index
    
    # Drop the 'group_id' column for the feature set
    X = df.drop(columns=exclude_cols + ['group_id'])
    y = df[target_col]
    
    # Split the data into training and test sets
    X_train = X.loc[train_indices]
    X_test = X.loc[test_indices]
    y_train = y.loc[train_indices]
    y_test = y.loc[test_indices]
    
    # Check class distributions to confirm stratification
    print("Original label distribution:", df[target_col].value_counts().to_dict())
    print("Training label distribution:", y_train.value_counts().to_dict())
    print("Testing label distribution:", y_test.value_counts().to_dict())
    
    # Ensure no group disruption across train and test sets
    disrupted_groups = set(group_train).intersection(group_test)
    if disrupted_groups:
        print(f"Disrupted groups: {disrupted_groups}")
    else:
        print("No biological replicate disruption across training and test sets.")
    
    return X_train, X_test, y_train, y_test

# %% [markdown]
# # Run the function to split the data taking care of biological replicate disruption across training and test sets

# %%
# Run the function to split the data
X_train, X_test, y_train, y_test = split_train_test(
    df=filtered_df,  # Your DataFrame
    target_col='temp_class_label',  # Target column name
    exclude_cols=[
        'Class_label_sum', 'cell_line', 'condition', 'Gene_combination', 
        'Class_label_exp', 'Class_label_dep', 'Class_label_corr', 
        'Class_label_neg', 'temp_class_label', 'escore', 'score'
    ],  # Columns to exclude from features
    group_by_cols=['Gene_combination'],  # Group by Gene_combination
    test_size=0.2,  # 20% of the data for testing
    random_state=42  # Set random state for reproducibility
)

# Get the column names of X_train
column_names = X_train.columns.tolist()
print(column_names)
# Out:
# Original label distribution: {0: 5690, 1: 1677}
# Training label distribution: {0: 4557, 1: 1340}
# Testing label distribution: {0: 1133, 1: 337}
# No biological replicate disruption across training and test sets.
# ['single_gene_highist_avg_lfc', 'single_gene_lowest_avg_lfc', 'expected_combinatorial_lfc', 'combinatorial_avg_lfc', 'Euclidean_distance_expexted_observed', 'Euclidean_distance_singel_phenotype', 'highist_expression', 'lowest_expression', 'Euclidean_distance_expresstion', 'expre_Correlation', 'highist_dep', 'lowest_dep', 'Euclidean_distance_dep', 'dep_Correlation', 'highist_damage_mutation', 'lowest_damage_mutation', 'Euclidean_distance_dm', 'Jaccard BP Similarity', 'Jaccard MF Similarity', 'Jaccard CC Similarity', 'Average Wang BP Similarity', 'Average Wang MF Similarity', 'Average Wang CC Similarity', 'nscore', 'fscore', 'pscore', 'ascore', 'dscore', 'Jaccard Index_commun_proteins', 'Number of Common Proteins']

# %% [markdown]
# # PLot mutibel matrixes in split data

# %%
classifiers = {
    'DummyClassifier' :DummyClassifier(),
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(random_state=42),
    'SVM': SVC(probability=True, random_state=42),  
    'KNN': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB(),
    
}
results_df = fit_and_evaluate_classifiers(classifiers, X_train, y_train, X_test, y_test, group=1)
# Out:
# Training DummyClassifier...
# Training Logistic Regression...
# Training Random Forest...
# /home/user/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training SVM...
# Training KNN...
# Training Naive Bayes...
#
# Performance Metrics:
#             Classifier       AUC  Accuracy  Precision    Recall  F1-Score
# 0      DummyClassifier  0.500000  0.770748   0.000000  0.000000  0.000000
# 1  Logistic Regression  0.835863  0.813605   0.700637  0.326409  0.445344
# 2        Random Forest  0.897853  0.858503   0.808612  0.501484  0.619048
# 3                  SVM  0.805440  0.791837   0.706667  0.157270  0.257282
# 4                  KNN  0.732547  0.770068   0.497175  0.261128  0.342412
# 5          Naive Bayes  0.813541  0.793878   0.546703  0.590504  0.567760

# %% [markdown]
# # 3 - Handling inblaaced methods using diffrent methods for implance data

# %% [markdown]
# # Genral function to plot data size before and after oversampling

# %%
# Define the plot_class_distribution function
def plot_class_distribution(df, y_original, y_resampled, technique_name):
    # Extract class distribution
    original_distribution = Counter(y_original)
    resampled_distribution = Counter(y_resampled)

    # Extract class labels and counts
    classes = list(original_distribution.keys())  # Unique class labels
    original_counts = [original_distribution.get(cls, 0) for cls in classes]
    resampled_counts = [resampled_distribution.get(cls, 0) for cls in classes]

    # Create side-by-side histograms
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))

    # Original dataset histogram
    ax[0].bar(classes, original_counts, color='skyblue')
    ax[0].set_title('Original Dataset Class Distribution')
    ax[0].set_xlabel('Classes')
    ax[0].set_ylabel('Count')
    ax[0].set_xticks(classes)

    # Resampled dataset histogram
    ax[1].bar(classes, resampled_counts, color='lightgreen')
    ax[1].set_title(f'Resampled Dataset Class Distribution using {technique_name}')
    ax[1].set_xlabel('Classes')
    ax[1].set_ylabel('Count')
    ax[1].set_xticks(classes)

    # Adjust layout
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # General function to train one classaafaier but with  multipel train set

# %%
def plot_custom_confusion_matrices_single_classifier(
    classifier, 
    training_sets, 
    X_test, 
    y_test, 
    class_order=[1, 0], 
    display_labels=['GI', 'No GI']
):
    """
    Plots confusion matrices for a single classifier with different training datasets.
    
    Parameters:
    - classifier: A single classifier object (e.g., LogisticRegression())
    - training_sets: A dictionary where keys are dataset names (e.g., preprocessing techniques) and values are 
                     tuples (X_train, y_train) for different training datasets.
    - X_test: Test data features
    - y_test: Test data labels
    - class_order: List of class indices in desired order (default [1, 0])
    - display_labels: List of display labels in desired order (default ['GI', 'No GI'])

    Returns:
    - Plots confusion matrices for the classifier trained on each dataset.
    """
    from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
    import matplotlib.pyplot as plt

    for dataset_name, (X_train, y_train) in training_sets.items():
        print(f"Training on dataset '{dataset_name}'...")

        # Train classifier on the current training dataset
        clf = classifier
        clf.fit(X_train, y_train)
        
        # Make predictions on the test set
        y_test_pred = clf.predict(X_test)
        
        # Compute confusion matrix
        cm_test = confusion_matrix(y_test, y_test_pred)
        
        # Reorder confusion matrix based on class_order
        cm_test_reordered = cm_test[class_order][:, class_order]
        
        # Create ConfusionMatrixDisplay for the test set
        disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test_reordered, display_labels=display_labels)
        
        # Create a figure for each training dataset
        fig, ax = plt.subplots(figsize=(6, 6))
        
        # Plot test confusion matrix
        disp_test.plot(cmap=plt.cm.Blues, values_format='d', ax=ax)
        ax.set_title(f'{dataset_name}: Test Set Confusion Matrix')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Function to plot diffrent sampel using one classafier

# %%
def fit_and_evaluate_single_classifier(
    classifier, 
    training_sets, 
    X_test, 
    y_test, 
    group=1
):
    """
    Fit a single classifier on different training datasets, calculate performance metrics, and visualize results.

    Parameters:
    - classifier: A single classifier object (e.g., LogisticRegression()).
    - training_sets: Dictionary of training dataset names and their data tuples (e.g., {'Original': (X_train, y_train)}).
    - X_test: Test feature set.
    - y_test: Test labels.
    - group: The class label considered as the positive class (default is 1).

    Returns:
    - Pandas DataFrame with performance metrics (AUC, Accuracy, Precision, Recall, F1-score) for each dataset.
    """
    from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, f1_score
    import pandas as pd
    import seaborn as sns
    import matplotlib.pyplot as plt

    # Check for training and testing data
    if any(data is None for data in [X_test, y_test]):
        raise ValueError("Test data must be provided.")
    if not training_sets:
        raise ValueError("Training sets must be provided.")
    
    # Initialize a list to store results
    results = []

    for dataset_name, (X_train, y_train) in training_sets.items():
        print(f"Training on dataset: '{dataset_name}'")

        # Fit the classifier on the current training data
        clf = classifier
        clf.fit(X_train, y_train)

        # Calculate AUC if supported
        if hasattr(clf, 'predict_proba'):
            y_scores = clf.predict_proba(X_test)[:, group]
            auc_value = roc_auc_score(y_test, y_scores)
        else:
            print(f"{type(clf).__name__} does not support predict_proba, skipping AUC calculation.")
            auc_value = None

        # Get predicted labels
        y_pred = clf.predict(X_test)

        # Calculate performance metrics
        accuracy = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, pos_label=group, zero_division=0)
        recall = recall_score(y_test, y_pred, pos_label=group)
        f1 = f1_score(y_test, y_pred, pos_label=group)

        # Append results with dataset name
        results.append({
            'Dataset': dataset_name,
            'AUC': auc_value,
            'Accuracy': accuracy,
            'Precision': precision,
            'Recall': recall,
            'F1-Score': f1
        })

    # Convert results to a DataFrame
    results_df = pd.DataFrame(results)

    # Display the results
    print("\nPerformance Metrics:")
    print(results_df)

    # Visualize the results as scatter plots
    melted_df = results_df.melt(id_vars=['Dataset'], 
                                value_vars=['AUC', 'Accuracy', 'Precision', 'Recall', 'F1-Score'], 
                                var_name='Metric', 
                                value_name='Value')

    plt.figure(figsize=(12, 8))
    sns.scatterplot(
        data=melted_df, 
        x='Metric', 
        y='Value', 
        hue='Dataset', 
        style='Dataset', 
        s=100, 
        palette='tab10'
    )
    plt.title('Classifier Performance Metrics Across Datasets')
    plt.ylabel('Metric Value')
    plt.xlabel('Metric')
    plt.ylim(0, 1.1)  
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Dataset')
    plt.tight_layout()
    plt.show()

    return results_df

# %% [markdown]
# # A ) Random over-sampling with imblearn

# %%
# Define classifiers
classifiers = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(random_state=42),
}
# Initialize RandomOverSampler
ros = RandomOverSampler()
# Perform random oversampling (use fit_resample instead of fit_sample)
X_train_ros, y_train_ros = ros.fit_resample(X_train, y_train)

# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df, y_train, y_train_ros, "RandomOverSampler from imblearn")

# %% [markdown]
# # 2 Synthetic Minority Oversampling Technique (SMOTE)
# '''SMOTE algorithm works in 4 simple steps:
#
# Choose a minority class as the input vector
# Find its k nearest neighbors (k_neighbors is specified as an argument in the SMOTE() function)
# Choose one of these neighbors and place a synthetic point anywhere on the line joining the point under consideration and its chosen neighbor
# Repeat the steps until data is balanced'''

# %%
# from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import SMOTE

# create the  object with the desired sampling strategy.
smote = SMOTE(sampling_strategy='minority',random_state=42)

# fit the object to our training data
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# plot using the  plot_class_distribution function:
plot_class_distribution(df1,y_train, y_train_smote, "SMOTE")

# %% [markdown]
# # 3- Borderline-SMOTE
# 1- classafy majorit and minority class
# 2-Select the misclassafication class by using KNN for exampel if it is 3 it will draw line between 3 neigboring data and it will attach to other group it will misclassafiy.This is means the data in the border will be misclassafyfrom minority class
# 3- it will add new syntatatic point to misclalassafied point using SMOTE (multiplipcated a random number between 0 and 1)
# Borderline-SMOTE1 (as discribed early )
# Borderline-SMOTE2 (step 2 focusin both class and using the nuber between 0 and 0,5)
#
# The assumption is that these borderline instances are more informative for the classifier, so augmenting them with synthetic data helps the model better learn the decision boundary.
#
# # Why Add Synthetic Points Near the Border:
# Improve decision boundary: By adding synthetic points near the border, BORDLINE-SMOTE helps to better define the boundary between the majority and minority classes, allowing classifiers to learn a more accurate separation.
#
# Reduce misclassification: Classifiers often misclassify minority samples near the boundary as majority samples. By enriching this region with synthetic samples, the classifier is better trained to correctly classify borderline minority instances.
#
# Address imbalance in critical areas: Traditional SMOTE may oversample areas far from the decision boundary, which may not contribute to improved classification performance. BORDLINE-SMOTE targets the critical regions near the boundary where the classification problem is more challenging.
#
#
#
# # The drawback of this method
# 1- Noisy data near the decision boundary:
# Some of these samples might be outliers, mislabelled data, or simply noisy instances
#
# # Solutions to Mitigate This Problem:
#
#
# 1-Tomek Links (BORDLINE-SMOTE + Tomek Links):
#
#  can be used after BORDLINE-SMOTE to identify and remove borderline instances that are too close to majority class instances. A Tomek Link exists when two nearest neighbor instances belong to different classes. By removing these pairs, you can clean up noisy samples that are too close to the boundary, reducing overlap between classes.
# 2- Cleaning techniques (Edited Nearest Neighbors, ENN):
#
# 3-Techniques like Edited Nearest Neighbors (ENN) can be applied before BORDLINE-SMOTE to clean up noisy data points. ENN removes samples that are misclassified by their nearest neighbors, which helps in filtering out noisy or misclassified data points before generating synthetic samples.
# Adaptive SMOTE (ADASYN):
#
# 4-ADASYN (Adaptive Synthetic Sampling) is another variant of SMOTE that addresses this issue by generating more synthetic points in areas where there are fewer minority class samples, and fewer synthetic points in denser minority regions. It focuses on difficult-to-learn examples but attempts to reduce the risk of oversampling noisy borderline points.
# Advanced Outlier Detection:
#
# 5-Implementing an outlier detection mechanism before applying BORDLINE-SMOTE can help detect and remove potential noisy or mislabelled samples. Techniques like Local Outlier Factor (LOF) or Isolation Forests can help flag these outliers for removal.
# Borderline-SMOTE2:

# %%
# from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import BorderlineSMOTE

# fit the object to our training data
bsmote1 = BorderlineSMOTE(kind = 'borderline-1',sampling_strategy='minority',random_state = 42)

# fit the object to our training data
X_train_bsmote1, y_train_bsmote1 = bsmote1.fit_resample(X_train, y_train)

# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df, y_train, y_train_bsmote1, "BorderlineSMOTE 1")

# %% [markdown]
# # 4_ BorderlineSMOTE 2

# %%
# Initialize the BorderlineSMOTE object
bsmote2 = BorderlineSMOTE(kind='borderline-2', sampling_strategy='minority', random_state=42)

# Apply BorderlineSMOTE to the training data
X_train_bsmote2, y_train_bsmote2 = bsmote2.fit_resample(X_train, y_train)


# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df,y_train, y_train_bsmote2,"BorderlineSMOTE 2")

# %% [markdown]
# # 5- Borderline-SMOTE SVM
#
# In the SVM-SMOTE, the borderline area is approximated by the support vectors (maximizing the area between two classes ) after training SVMs classifier on the original training set. Synthetic data will be randomly created along the lines joining each minority class support vector with a number of its nearest neighbors. What special about Borderline-SMOTE SVM compared to the Borderline-SMOTE is that more data are synthesized away from the region of class overlap. It focuses more on where the data is separated.
# The focus lyes on between where minumm class found, compared to the border.

# %%
# from imblearn.over_sampling import SVMSMOTE
from imblearn.over_sampling import SVMSMOTE
# applay svmsmote
svmsmote = SVMSMOTE(sampling_strategy='minority',random_state = 42)
# fit the object to our training data
X_train_svmsmote, y_train_svmsmote= svmsmote.fit_resample(X_train, y_train)

# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df,y_train, y_train_svmsmote," Borderline-SMOTE SVM ")

# %% [markdown]
# # 6- KMeansSMOTE
#
# K-Means SMOTE works in three steps:
#
# Cluster the entire input space using k-means.
# Distribute the number of samples to generate across clusters:
# Select clusters which have a high number of minority class samples.
# Assign more synthetic samples to clusters where minority class samples are sparsely distributed.
# Oversample each filtered cluster using SMOTE.

# %%
from imblearn.over_sampling import KMeansSMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scale = StandardScaler()
X_train_scale = scale.fit_transform(X_train)

### Elbow method to find the No of cluster using WSS
wss = []
cluster = list(range(1,12))

for k in cluster:
    kmean = KMeans(n_clusters= k,init="k-means++",random_state = 42)
    kmean.fit(X_train_scale)
    wss.append(kmean.inertia_)

plt.title("Elbow Method to find Cluster")
sns.lineplot(x=cluster,y=wss)
plt.ylabel("Within Sum of Squares(wss)")
plt.xlabel("No of Cluster")

ksmote = KMeansSMOTE(
    sampling_strategy='minority',
    k_neighbors=2,
    kmeans_estimator=4,
    cluster_balance_threshold=0.02,
    density_exponent='auto')

# fit the object to our training data
X_train_ksmote, y_train_ksmote = ksmote.fit_resample(X_train, y_train)

# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df,y_train, y_train_ksmote," KMeansSMOTE ")

# %% [markdown]
# # 7- Oversampling with Adaptive Synthetic sampling(ADASYN)
#
#
# It measures the K-nearest neighbors for all minority instances, then calculates the class ratio of the minority and majority instances to create new samples. Repeating this process, we will adaptively shift the decision boundary to focus on those samples that are hard to learn. The synthetic data generation would inversely proportional to the density of the minority class. It means more synthetic data are created in regions of the feature space where the density of minority examples is low, and fewer or none where the density is high. In simpler terms, in an area where the minority class is less dense, the synthetic data are created more. Otherwise, the synthetic data is not made so much.

# %%
# from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import ADASYN

# create the object to resample the majority class.
adasyn = ADASYN(sampling_strategy="minority",random_state=42)

# fit the object to the training data.
X_train_adasyn, y_train_adasyn = adasyn.fit_resample(X_train, y_train)

# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df,y_train, y_train_adasyn," ADASYN ")

# %% [markdown]
# # 8_TomekLinks
# Undersamplings method to remove the majority class in border

# %%
# from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import TomekLinks
# Apply Tomek Links to clean training data
tomek = TomekLinks()
X_tomek, y_tomek = tomek.fit_resample(X_train, y_train)

# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df,y_train, y_tomek," Tomek ")

# %% [markdown]
# #  9-k-nearest neighbors (KNN)
# Nearest Neighbors: ENN uses the k-nearest neighbors (KNN) algorithm to decide whether to remove a sample. It checks each instance in the dataset against its nearest neighbors.
#
# Noise Reduction: If a sample's class label differs from the majority of its nearest neighbors, the sample is considered noisy and is removed from the dataset.
#
# Class Boundary Refinement: By removing noisy samples, ENN helps to smooth the class boundaries, making it easier for a classifier to distinguish between different classes.

# %%
# from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.under_sampling import EditedNearestNeighbours
# : Apply Edited Nearest Neighbors (ENN)

enn = EditedNearestNeighbours(n_neighbors=3)  
X_enn, y_enn = enn.fit_resample(X_train, y_train)

# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df,y_train, y_enn," k-nearest neighbors (KNN) ")

# %% [markdown]
#  # 10- tomek undersamplingmethod for cleaning + oversamling using BorderlineSMOTE SVM

# %%
# from imblearn.over_sampling import SVMSMOTE
from imblearn.over_sampling import SVMSMOTE
# from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import TomekLinks

# Apply Tomek Links to clean training data
tomek = TomekLinks()
X_tomek, y_tomek = tomek.fit_resample(X_train, y_train)

# applay svmsmote to undersampling methods tomek
svmsmote = SVMSMOTE(sampling_strategy='minority',random_state = 42)
# fit the object to our training data
X_train_tomek_svmsmote, y_train_tomek_svmsmote= svmsmote.fit_resample(X_tomek, y_tomek)


# plot using the  plot_class_distribution function:
plot_class_distribution(filtered_df,y_train, y_train_tomek_svmsmote," tomek+SVMSMOTE")

# %%
# Dictionary of training datasets
training_sets = {
    'Original Data': (X_train, y_train),
    'RandomOverSampler': (X_train_ros, y_train_ros),
    'SMOTE'   :(X_train_smote, y_train_smote),
    'BorderlineSMOTE 1':(X_train_bsmote1, y_train_bsmote1 ),
    'BorderlineSMOTE 2':(X_train_bsmote2, y_train_bsmote2 ),
    'Borderline-SMOTE SVM ':(X_train_svmsmote, y_train_svmsmote),
    'KMeansSMOTE':(X_train_ksmote, y_train_ksmote ),
    'ADASYN': (X_train_adasyn, y_train_adasyn),
    'Tomek': (X_tomek, y_tomek),
    'k-nearest neighbors (KNN)': (X_enn, y_enn ),
    'Tomek+ Borderline-SMOTE SVM': (X_train_tomek_svmsmote, y_train_tomek_svmsmote)
    }

# Single classifier
classifier =  RandomForestClassifier(random_state=42)

# Call the function
plot_custom_confusion_matrices_single_classifier(
    classifier=classifier,
    training_sets=training_sets,
    X_test=X_test,
    y_test=y_test
)
# Out:
# Training on dataset 'Original Data'...
# Training on dataset 'RandomOverSampler'...
# Training on dataset 'SMOTE'...
# Training on dataset 'BorderlineSMOTE 1'...
# Training on dataset 'BorderlineSMOTE 2'...
# Training on dataset 'Borderline-SMOTE SVM '...
# Training on dataset 'KMeansSMOTE'...
# Training on dataset 'ADASYN'...
# Training on dataset 'Tomek'...
# Training on dataset 'k-nearest neighbors (KNN)'...
# Training on dataset 'Tomek+ Borderline-SMOTE SVM'...

# %% [markdown]
# # Call the function for diffrance matrixes using Randomforest

# %%
# Call the function
results_df = fit_and_evaluate_single_classifier(
    classifier=classifier, 
    training_sets=training_sets, 
    X_test=X_test, 
    y_test=y_test
)
# Out:
# Training on dataset: 'Original Data'
# Training on dataset: 'RandomOverSampler'
# Training on dataset: 'SMOTE'
# Training on dataset: 'BorderlineSMOTE 1'
# Training on dataset: 'BorderlineSMOTE 2'
# Training on dataset: 'Borderline-SMOTE SVM '
# Training on dataset: 'KMeansSMOTE'
# Training on dataset: 'ADASYN'
# Training on dataset: 'Tomek'
# Training on dataset: 'k-nearest neighbors (KNN)'
# Training on dataset: 'Tomek+ Borderline-SMOTE SVM'
#
# Performance Metrics:
#                         Dataset       AUC  Accuracy  Precision    Recall  \
# 0                 Original Data  0.897853  0.858503   0.808612  0.501484
# 1             RandomOverSampler  0.895544  0.857143   0.761317  0.548961
# 2                         SMOTE  0.887760  0.844218   0.691489  0.578635
# 3             BorderlineSMOTE 1  0.893072  0.857823   0.725352  0.611276
# 4             BorderlineSMOTE 2  0.885751  0.851701   0.713262  0.590504
# 5         Borderline-SMOTE SVM   0.893255  0.853741   0.706081  0.620178
# 6                   KMeansSMOTE  0.886596  0.853741   0.717857  0.596439
# 7                        ADASYN  0.888850  0.853061   0.706485  0.614243
# 8                         Tomek  0.899008  0.861905   0.781513  0.551929
# 9     k-nearest neighbors (KNN)  0.886975  0.817687   0.582339  0.724036
# 10  Tomek+ Borderline-SMOTE SVM  0.896158  0.857823   0.703822  0.655786
#
#     F1-Score
# 0   0.619048
# 1   0.637931
# 2   0.630048
# 3   0.663446
# 4   0.646104
# 5   0.660348
# 6   0.651540
# 7   0.657143
# 8   0.646957
# 9   0.645503
# 10  0.678955

# %% [markdown]
# # Create general function that can discover which moste predictive features
# In this function the Randomforest classafoer will be trained, aftethat Feature importances calculated  based on the mean decrease in impurity are computed using model.feature_importances_. The standard deviation of feature importances across all trees in the random forest is computed using np.std(). The output will be  a bar chart with values.
#
# INthe second, the permutation_importance() function is used to compute feature importance based on accuracy. It used n_repeats=10 ,meaning the every features shuffeled 10 times and calculted the performance , and afterthat calculated the means of the perfomance. It will used accuracy and F1 score for the prediction of moste predictive featiure. It is used Gini impurity
#
#
# They are two ways used to discover most predictive features, MDI (Mean Decrease in Impurity), it messure the feature importance based on how the feature reduce the impuritey when it split the sampels in the tree.
# For each tree, the importance of a feature is computed by summing the reduction in impurity for all splits where that feature was used.THen the feature importance across all trees is averaged to give the final importance score for each feature
#
#  Permutation Importance calculated by train the model in the classafeir, Calculate the baseline performance, Shuffle the values of one feature ,After shuffling the feature values, the model is re-evaluated on the modified test set to see how the performance changes.
#  The decrease in performance is calculated by comparing the model's performance on the shuffled test set to the baseline performance. The greater the performance decrease, the more important the feature is.
#
#  MDI is more senseitive the more correlated features but Permutation is more restrictive against correlated features.

# %%
def feature_importance_analysis(X_train, y_train, X_test, y_test):
    """
    Perform feature importance analysis using both Mean Decrease in Impurity (MDI) and Permutation Importance
    on a Random Forest model. The function trains the model, calculates feature importances, and visualizes the results.
    This function relies on:
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    from sklearn.inspection import permutation_importance
    from sklearn.ensemble import RandomForestClassifier
    import time

    Parameters:
    - X_train: Features of the training dataset.
    - y_train: Target labels for the training dataset.
    - X_test: Features of the test dataset.
    - y_test: Target labels for the test dataset.
    
    Returns:
    - forest_importances (pd.Series): Feature importances calculated using Mean Decrease in Impurity (MDI).
    - forest_importances_perm (pd.Series): Feature importances calculated using Permutation Importance (Accuracy).
    - forest_importances_perm_f1 (pd.Series): Feature importances calculated using Permutation Importance (F1 score).
    """
    # Step 1: Train the RandomForest model
    model = RandomForestClassifier(random_state=42
    
    )
    model.fit(X_train, y_train)
    
    feature_names = X_train.columns

    # Step 2: Feature Importance using Mean Decrease in Impurity (MDI)
    start_time = time.time()
    importances = model.feature_importances_  
    std = np.std([tree.feature_importances_ for tree in model.estimators_], axis=0)
    elapsed_time = time.time() - start_time
    print(f"Elapsed time to compute the importances (MDI): {elapsed_time:.3f} seconds")
    
    # MDI Feature Importance DataFrame
    forest_importances = pd.Series(importances, index=feature_names).sort_values(ascending=False)

    # Plot MDI Feature Importances
    fig, ax = plt.subplots()
    forest_importances.plot.bar(yerr=std[np.argsort(-importances)], ax=ax)
    ax.set_title("Feature importances using MDI")
    ax.set_ylabel("Mean decrease in impurity")
    plt.xticks(rotation=90, ha='center', fontsize=10) 
    fig.tight_layout()
    plt.show()

    # Step 3: Feature Importance using Permutation (Accuracy)
    start_time = time.time()
    result = permutation_importance(
        model, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2, scoring="accuracy"
    )
    elapsed_time = time.time() - start_time
    print(f"Elapsed time to compute the importances (permutation with accuracy): {elapsed_time:.3f} seconds")
    
    # Permutation Importance (Accuracy)
    forest_importances_perm = pd.Series(result.importances_mean, index=feature_names).sort_values(ascending=False)

    # Plot Permutation Feature Importances (Accuracy)
    fig, ax = plt.subplots()
    forest_importances_perm.plot.bar(yerr=result.importances_std[np.argsort(-result.importances_mean)], ax=ax)
    ax.set_title("Feature importances using permutation (Accuracy)")
    ax.set_ylabel("Mean accuracy decrease")
    plt.xticks(rotation=75, ha='right', fontsize=12)
    fig.tight_layout()
    plt.show()

    # Step 4: Feature Importance using Permutation (F1 score)
    start_time = time.time()
    result_f1 = permutation_importance(
        model, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2, scoring="f1"
    )
    elapsed_time = time.time() - start_time
    print(f"Elapsed time to compute the importances (permutation with F1 score): {elapsed_time:.3f} seconds")
    
    # Permutation Importance (F1 score)
    forest_importances_perm_f1 = pd.Series(result_f1.importances_mean, index=feature_names).sort_values(ascending=False)

    # Plot Permutation Feature Importances (F1 score)
    fig, ax = plt.subplots()
    forest_importances_perm_f1.plot.bar(yerr=result_f1.importances_std[np.argsort(-result_f1.importances_mean)], ax=ax)
    ax.set_title("Feature importances using permutation (F1 score)")
    ax.set_ylabel("Mean F1 score decrease")
    plt.xticks(rotation=90, ha='center', fontsize=10) 
    fig.tight_layout()
    plt.show()

    # Return the feature importance dataframes
    return forest_importances, forest_importances_perm, forest_importances_perm_f1

# %% [markdown]
# # Call the function to analyse feature imortance

# %%
# Call the function 
forest_importances, forest_importances_perm, forest_importances_perm_f1 = feature_importance_analysis(X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test)

# Now you can inspect the DataFrames:
print("Feature importances (MDI):")
print(forest_importances)
print("Feature importances (Permutation - Accuracy):")
print(forest_importances_perm)
print("Feature importances (Permutation - F1 score):")
print(forest_importances_perm_f1)
# Out:
# Elapsed time to compute the importances (MDI): 0.010 seconds
# Elapsed time to compute the importances (permutation with accuracy): 3.944 seconds
# Elapsed time to compute the importances (permutation with F1 score): 4.413 seconds
# Feature importances (MDI):
# pscore                                  0.118930
# ascore                                  0.093665
# Jaccard Index_commun_proteins           0.076803
# Number of Common Proteins               0.061114
# Average Wang BP Similarity              0.061105
# highist_expression                      0.047110
# lowest_expression                       0.045042
# Average Wang CC Similarity              0.041431
# Euclidean_distance_expexted_observed    0.037830
# Average Wang MF Similarity              0.034710
# expre_Correlation                       0.033064
# dep_Correlation                         0.031044
# Jaccard BP Similarity                   0.030334
# dscore                                  0.027330
# Jaccard MF Similarity                   0.027135
# Jaccard CC Similarity                   0.026851
# Euclidean_distance_expresstion          0.026458
# expected_combinatorial_lfc              0.026028
# single_gene_highist_avg_lfc             0.024405
# combinatorial_avg_lfc                   0.024302
# lowest_dep                              0.022227
# single_gene_lowest_avg_lfc              0.021509
# highist_dep                             0.021393
# Euclidean_distance_dep                  0.020054
# Euclidean_distance_singel_phenotype     0.019609
# Euclidean_distance_dm                   0.000271
# highist_damage_mutation                 0.000241
# nscore                                  0.000000
# fscore                                  0.000000
# lowest_damage_mutation                  0.000000
# dtype: float64
# Feature importances (Permutation - Accuracy):
# pscore                                  0.100952
# ascore                                  0.089116
# expre_Correlation                       0.009524
# Jaccard MF Similarity                   0.008844
# Euclidean_distance_expexted_observed    0.007279
# Jaccard Index_commun_proteins           0.006667
# Number of Common Proteins               0.006259
# highist_dep                             0.006259
# Average Wang MF Similarity              0.005714
# Average Wang BP Similarity              0.005442
# Euclidean_distance_expresstion          0.005374
# Jaccard CC Similarity                   0.004966
# Jaccard BP Similarity                   0.004694
# dep_Correlation                         0.004150
# Euclidean_distance_singel_phenotype     0.003946
# dscore                                  0.002449
# highist_expression                      0.002177
# Average Wang CC Similarity              0.001497
# lowest_dep                              0.001156
# fscore                                  0.000000
# nscore                                  0.000000
# lowest_damage_mutation                  0.000000
# Euclidean_distance_dm                   0.000000
# highist_damage_mutation                 0.000000
# Euclidean_distance_dep                 -0.000476
# combinatorial_avg_lfc                  -0.000680
# expected_combinatorial_lfc             -0.000748
# single_gene_lowest_avg_lfc             -0.002177
# single_gene_highist_avg_lfc            -0.002449
# lowest_expression                      -0.003878
# dtype: float64
# Feature importances (Permutation - F1 score):
# pscore                                  0.132163
# ascore                                  0.106295
# expre_Correlation                       0.019618
# Jaccard MF Similarity                   0.017896
# Euclidean_distance_expexted_observed    0.017208
# highist_dep                             0.015167
# highist_expression                      0.014192
# Average Wang MF Similarity              0.013113
# Average Wang BP Similarity              0.012116
# Jaccard CC Similarity                   0.011891
# Jaccard Index_commun_proteins           0.011180
# Euclidean_distance_expresstion          0.011180
# Euclidean_distance_singel_phenotype     0.010130
# Average Wang CC Similarity              0.007827
# dep_Correlation                         0.007425
# lowest_dep                              0.007209
# Jaccard BP Similarity                   0.004963
# Number of Common Proteins               0.003289
# fscore                                  0.000000
# nscore                                  0.000000
# lowest_damage_mutation                  0.000000
# Euclidean_distance_dm                   0.000000
# highist_damage_mutation                 0.000000
# Euclidean_distance_dep                 -0.000037
# expected_combinatorial_lfc             -0.000563
# lowest_expression                      -0.001135
# single_gene_highist_avg_lfc            -0.001499
# combinatorial_avg_lfc                  -0.002322
# single_gene_lowest_avg_lfc             -0.002665
# dscore                                 -0.007199
# dtype: float64

# %% [markdown]
# # Selected the obtimal number of features
#
# Benefits of Using RFECV:
# Automated Feature Selection: No need to manually tune the number of features to retain.
# Improved Model Performance: Retains only the most informative features, which can improve generalization.
# Reduced Overfitting: Eliminates irrelevant or noisy features.
# Insights on Feature Importance: Provides a ranking of features based on their importance to the model.
# Result :
# Optimal features: 5
# feature indices 9, 13, 20, 23, and 25 were chosen
# Most Important Features (Rank 1): ['expre_Correlation', 'dep_Correlation', 'Average Wang BP Similarity', 'Average Wang CC Similarity', 'pscore']
# Most Important Features (Rank 4): ['Euclidean_distance_expexted_observed']

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold

rf = RandomForestClassifier(random_state=42)
cv = StratifiedKFold(n_splits=5)

rfecv = RFECV(estimator=rf, step=1, cv=cv,scoring='f1')
rfecv.fit(X_train_tomek_svmsmote, y_train_tomek_svmsmote)

print("Optimal number of features:", rfecv.n_features_)
print("Selected Features Mask:", rfecv.support_)
print("Feature Ranking:", rfecv.ranking_)
# Out:
# Optimal number of features: 16
# Selected Features Mask: [False False  True False  True False  True  True  True  True False False
#  False  True False False False  True  True False  True  True  True False
#  False  True  True False  True  True]
# Feature Ranking: [ 5  7  1  3  1 10  1  1  1  1  8  6  9  1 11 13 12  1  1  2  1  1  1 14
#  15  1  1  4  1  1]

# %% [markdown]
# # Get features ranked with number one

# %%
# Get the features with ranking 1
important_features = X_train.columns[rfecv.ranking_ == 1]
print("Most Important Features (Rank 1):", important_features.tolist())
# Out:
# Most Important Features (Rank 1): ['expected_combinatorial_lfc', 'Euclidean_distance_expexted_observed', 'highist_expression', 'lowest_expression', 'Euclidean_distance_expresstion', 'expre_Correlation', 'dep_Correlation', 'Jaccard BP Similarity', 'Jaccard MF Similarity', 'Average Wang BP Similarity', 'Average Wang MF Similarity', 'Average Wang CC Similarity', 'pscore', 'ascore', 'Jaccard Index_commun_proteins', 'Number of Common Proteins']

# %% [markdown]
# # General function to extract the positive class and totalt data from random forst

# %%
def random_forest_extract(X_train, y_train, X_test, y_test, positive_class=1):
    """
    Train and evaluate a Random Forest classifier, and extract predictions for a specified class.
    
    Parameters:
    - X_train: Training features (DataFrame or array).
    - y_train: Training labels (Series or array).
    - X_test: Test features (DataFrame or array).
    - y_test: Test labels (Series or array).
    - positive_class: The class for which predictions are extracted (default is 1).

    Returns:
    - results_df: DataFrame containing True labels, Predicted labels, and class probabilities.
    - class_predictions: DataFrame containing samples predicted as the specified positive class.
    - classification_report_dict: Dictionary containing classification metrics.
    """
    # Step 1: Train the Random Forest model
    model = RandomForestClassifier(
    random_state=42)

    model.fit(X_train, y_train)

    # Step 2: Get predictions
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)

    # Step 3: Create a DataFrame to hold predictions and probabilities
    results_df = pd.DataFrame(X_test, columns=X_train.columns)  # Use original column names if available
    results_df['True_Label'] = y_test
    results_df['Predicted_Label'] = y_pred
    results_df[f'Probability_Class_{positive_class}'] = y_proba[:, positive_class]

    # Step 4: Filter for samples predicted as the positive class
    class_predictions = results_df[results_df['Predicted_Label'] == positive_class]

    # Step 5: Classification Report
    classification_report_dict = classification_report(y_test, y_pred, output_dict=True)

    # Print the classification report for overall performance
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Return the full results, class predictions for the positive class, and metrics
    return results_df, class_predictions, classification_report_dict

# %% [markdown]
# # Extract the GI predicted

# %%
# Run the workflow
results_df, class_1_predictions, metrics = random_forest_extract(X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test, positive_class=1)

# Display samples predicted as class 1
print("\nSamples Predicted as Class 1:")
print(class_1_predictions)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1133
#            1       0.70      0.66      0.68       337
#
#     accuracy                           0.86      1470
#    macro avg       0.80      0.79      0.79      1470
# weighted avg       0.85      0.86      0.86      1470
#
#
# Samples Predicted as Class 1:
#       single_gene_highist_avg_lfc  single_gene_lowest_avg_lfc  \
# 57                      -0.228091                   -4.213308
# 65                       0.280274                   -0.666132
# 93                      -0.814876                   -0.944811
# 98                      -1.290414                   -1.816571
# 150                      0.226842                   -0.056849
# ...                           ...                         ...
# 7543                    -0.760543                   -3.009782
# 7814                     0.307841                    0.000070
# 7888                     0.000070                   -0.080875
# 8341                    -0.115868                   -0.337268
# 8342                     0.698353                    0.528985
#
#       expected_combinatorial_lfc  combinatorial_avg_lfc  \
# 57                     -4.441399              -2.768200
# 65                     -0.385859              -0.622881
# 93                     -1.759687              -0.625027
# 98                     -3.106985              -1.111871
# 150                     0.169994               0.817874
# ...                          ...                    ...
# 7543                   -3.770325              -2.305693
# 7814                    0.307911               0.012349
# 7888                   -0.080805               0.179570
# 8341                   -0.453136               0.032322
# 8342                    1.227339               0.045212
#
#       Euclidean_distance_expexted_observed  \
# 57                                1.673198
# 65                                0.237022
# 93                                1.134660
# 98                                1.995113
# 150                               0.647880
# ...                                    ...
# 7543                              1.464632
# 7814                              0.295562
# 7888                              0.260375
# 8341                              0.485458
# 8342                              1.182126
#
#       Euclidean_distance_singel_phenotype  highist_expression  \
# 57                               3.985216            6.969679
# 65                               0.946406            3.173491
# 93                               0.129935            3.620200
# 98                               0.526158            2.851059
# 150                              0.283691            6.147752
# ...                                   ...                 ...
# 7543                             2.249239            3.712799
# 7814                             0.307771            2.312049
# 7888                             0.080945            4.260311
# 8341                             0.221400            2.994507
# 8342                             0.169368            1.869405
#
#       lowest_expression  Euclidean_distance_expresstion  expre_Correlation  \
# 57             4.604295                        2.365385           0.087346
# 65             2.927887                        0.245605           0.176581
# 93             3.616954                        0.003246           0.402737
# 98             2.700505                        0.150554           0.336011
# 150            0.103367                        6.044385           0.428503
# ...                 ...                             ...                ...
# 7543           3.388621                        0.324178           0.213836
# 7814           1.864575                        0.447474           0.400896
# 7888           1.864575                        2.395736           0.762634
# 8341           2.038642                        0.955865           0.754219
# 8342           1.776320                        0.093085           0.805059
#
#       ...  nscore  fscore  pscore  ascore  dscore  \
# 57    ...     0.0     0.0   0.000   0.000    0.00
# 65    ...     0.0     0.0   0.055   0.049    0.54
# 93    ...     0.0     0.0   0.049   0.092    0.90
# 98    ...     0.0     0.0   0.050   0.059    0.72
# 150   ...     0.0     0.0   0.067   0.072    0.00
# ...   ...     ...     ...     ...     ...     ...
# 7543  ...     0.0     0.0   0.000   0.000    0.00
# 7814  ...     0.0     0.0   0.064   0.055    0.00
# 7888  ...     0.0     0.0   0.080   0.096    0.00
# 8341  ...     0.0     0.0   0.000   0.000    0.00
# 8342  ...     0.0     0.0   0.000   0.000    0.00
#
#       Jaccard Index_commun_proteins  Number of Common Proteins  True_Label  \
# 57                         0.428571                          6           0
# 65                         0.176471                          3           0
# 93                         0.333333                          5           0
# 98                         0.666667                          8           1
# 150                        0.052632                          1           0
# ...                             ...                        ...         ...
# 7543                       0.111111                          2           0
# 7814                       0.428571                          6           1
# 7888                       0.250000                          4           1
# 8341                       0.076923                          1           1
# 8342                       0.111111                          2           1
#
#       Predicted_Label  Probability_Class_1
# 57                  1                 0.62
# 65                  1                 0.72
# 93                  1                 0.72
# 98                  1                 0.81
# 150                 1                 0.69
# ...               ...                  ...
# 7543                1                 0.58
# 7814                1                 0.96
# 7888                1                 0.91
# 8341                1                 0.65
# 8342                1                 0.52
#
# [314 rows x 33 columns]

# %% [markdown]
# # Merge column

# %%
# Merge the DataFrames based on common columns
common_columns = ['single_gene_highist_avg_lfc', 'single_gene_lowest_avg_lfc', 'expected_combinatorial_lfc',
                  'combinatorial_avg_lfc', 'Euclidean_distance_expexted_observed', 'Euclidean_distance_singel_phenotype',
                  'highist_expression', 'lowest_expression', 'Euclidean_distance_expresstion', 'highist_dep',
                  'fscore', 'pscore', 'ascore', 'dscore', 'Jaccard Index_commun_proteins', 
                  'Number of Common Proteins']

merged_df_positives = class_1_predictions.merge(
    filtered_df[['Class_label_sum','Class_label_exp', 'Class_label_dep','Class_label_corr','cell_line', 'condition', 'Gene_combination'] + common_columns],
    on=common_columns, how='left'
)

# %%
merged_df_positives
# Sort the DataFrame by the 'Score' column in descending order
df_sorted = merged_df_positives.sort_values(by='Probability_Class_1', ascending=False)
df_sorted
# Out:
#      single_gene_highist_avg_lfc  single_gene_lowest_avg_lfc  \
# 257                    -3.077791                   -3.659318
# 152                     0.007125                   -0.223408
# 310                     0.307841                    0.000070
# 119                    -0.299663                   -0.550673
# 250                     0.129023                   -0.748870
# ..                           ...                         ...
# 24                      0.433036                    0.351915
# 251                    -0.592434                   -0.748616
# 19                      1.072422                    0.486179
# 261                     0.307979                   -0.621663
# 98                     -0.607508                   -2.324724
#
#      expected_combinatorial_lfc  combinatorial_avg_lfc  \
# 257                   -6.737109              -2.655073
# 152                   -0.216283              -0.018338
# 310                    0.307911               0.012349
# 119                   -0.850336              -0.704547
# 250                   -0.619848              -0.182049
# ..                          ...                    ...
# 24                     0.784951               0.898109
# 251                   -1.341049              -0.278927
# 19                     1.558601               0.432621
# 261                   -0.313684               0.163514
# 98                    -2.932233              -2.883354
#
#      Euclidean_distance_expexted_observed  \
# 257                              4.082036
# 152                              0.197944
# 310                              0.295562
# 119                              0.145789
# 250                              0.437799
# ..                                    ...
# 24                               0.113158
# 251                              1.062123
# 19                               1.125980
# 261                              0.477198
# 98                               0.048879
#
#      Euclidean_distance_singel_phenotype  highist_expression  \
# 257                             0.581526            7.605290
# 152                             0.230533            4.312672
# 310                             0.307771            2.312049
# 119                             0.251009            7.073131
# 250                             0.877893            7.426641
# ..                                   ...                 ...
# 24                              0.081121            4.247816
# 251                             0.156182            6.107606
# 19                              0.586243            6.076451
# 261                             0.929642            3.067606
# 98                              1.717216            8.905052
#
#      lowest_expression  Euclidean_distance_expresstion  expre_Correlation  \
# 257           6.600122                        1.005169           0.334410
# 152           2.933445                        1.379226           0.488640
# 310           1.864575                        0.447474           0.400896
# 119           4.307946                        2.765185           0.204149
# 250           6.367170                        1.059471           0.149144
# ..                 ...                             ...                ...
# 24            1.534282                        2.713534           0.427169
# 251           2.536866                        3.570739           0.099876
# 19            3.419242                        2.657209           0.135309
# 261           1.624391                        1.443215           0.259109
# 98            5.115037                        3.790015          -0.061094
#
#      ...  True_Label  Predicted_Label  Probability_Class_1  Class_label_sum  \
# 257  ...           1                1                 0.99              lol
# 152  ...           1                1                 0.98            no GI
# 310  ...           1                1                 0.96            no GI
# 119  ...           1                1                 0.96            no GI
# 250  ...           1                1                 0.96            no GI
# ..   ...         ...              ...                  ...              ...
# 24   ...           1                1                 0.51            no GI
# 251  ...           0                1                 0.51            no GI
# 19   ...           1                1                 0.51            no GI
# 261  ...           1                1                 0.51            no GI
# 98   ...           0                1                 0.51            no GI
#
#      Class_label_exp  Class_label_dep  Class_label_corr  cell_line  condition  \
# 257               GI               GI             no GI    Meljuso    2CP sel
# 152               GI            no GI             no GI       A375        2CP
# 310               GI            no GI             no GI    Meljuso    2CP sel
# 119               GI            no GI             no GI       A375        2CP
# 250               GI            no GI             no GI    Meljuso    2CP sel
# ..               ...              ...               ...        ...        ...
# 24                GI            no GI             no GI       A375        2CP
# 251            no GI            no GI             no GI    Meljuso    2CP sel
# 19                GI            no GI             no GI       A375        2CP
# 261               GI            no GI             no GI    Meljuso    2CP sel
# 98             no GI            no GI             no GI       A375        2CP
#
#      Gene_combination
# 257       PSMC4_PSMC6
# 152    ZKSCAN1_ZNF397
# 310     ZNF232_ZNF397
# 119     SLC1A4_SLC1A5
# 250         PFKM_PFKP
# ..                ...
# 24       CRMP1_DPYSL3
# 251         PIM2_PIM3
# 19        CDK16_CDK18
# 261      RAB22A_RAB31
# 98       PSMB10_PSMB7
#
# [314 rows x 40 columns]

# %%
# Convert the 'Gene_combination' column to numeric, forcing errors to NaN
merged_df_positives['cell_line'] = pd.to_numeric(merged_df_positives['cell_line'], errors='coerce')

# Now count how many rows have 'Gene_combination' greater than 1
count_greater_than_1 = merged_df_positives[merged_df_positives['cell_line'] > 1].shape[0]

print(f"Number of rows where Gene_combination > 1: {count_greater_than_1}")
# Out:
# Number of rows where Gene_combination > 1: 0

# %% [markdown]
# # Export GI in document

# %%
merged_df_positives.to_csv('GI_prediction_expremint_label.csv', index=False)

# %% [markdown]
# # Hyperparameter tuninng
# Tuning of hyperparameter that help with class implance using GridSearchCV
#
# Two hyperparameter was diffrent from the defult
# Bootstrap: The model does not use bootstrap sampling, while the default uses bootstrap (sampling with replacement).
# max_depth: The model has a max depth of 30, while the default allows the trees to grow without a limit "all leaves are pure or until all leaves contain less than min_samples_split samples."
#
# #Training data used was X_train_tomek_svmsmote, y_train_tomek_svmsmote

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
# Create a RandomForestClassifier (with default settings for initial model)
rf = RandomForestClassifier(random_state=42)

# Define the hyperparameter grid for tuning
param_grid = {
    'n_estimators': [50, 100, 150,200,300],  # Different number of trees
    'max_depth': [None, 10, 20, 30,40],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum samples to split an internal node
    'min_samples_leaf': [1, 2, 4],    # Minimum samples at a leaf node
    'class_weight': ['balanced', None],  # Adjust weights for class imbalance
    'bootstrap': [True, False]        # Whether bootstrap samples are used
}

# Set up GridSearchCV with cross-validation
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='f1', n_jobs=-1, verbose=2)

# Fit the grid search tX_train_tomek_svmsmote, y_train_tomek_svmsmoteo the training data
grid_search.fit()
#Fit the grid search to the training data
grid_search.fit(X_train_tomek_svmsmote, y_train_tomek_svmsmote)


# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best hyperparameters found: ", best_params)
# Out:
# Fitting 5 folds for each of 900 candidates, totalling 4500 fits
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   7.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   7.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  11.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  11.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  14.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  15.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   6.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   7.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   7.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   9.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  11.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  11.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  11.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   7.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   7.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   7.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  14.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  16.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  14.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  17.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   8.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   9.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  15.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   6.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  17.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   7.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   7.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   8.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   9.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  10.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  10.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  14.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  14.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  17.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   7.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   7.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   9.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  11.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   8.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  10.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  15.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  15.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  14.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   5.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  17.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   6.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   8.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   9.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   9.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  13.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  14.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  13.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  15.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   7.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   6.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   7.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   7.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   7.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   9.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  10.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  10.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  10.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  15.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   4.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  15.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  14.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  16.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   5.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  15.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   9.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   9.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   9.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  10.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  10.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  11.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  13.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   3.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   2.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  18.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  17.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  18.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  18.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   7.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   7.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   7.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  10.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   2.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  13.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  14.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   7.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   6.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   7.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   6.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   9.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  16.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  13.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  15.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   7.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   7.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   7.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time=   7.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   9.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   9.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   9.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   9.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   3.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  13.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  14.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   4.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  14.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  13.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   5.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  14.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   6.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   8.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   6.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   8.0s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   7.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=   7.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.2s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.7s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   8.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.5s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   2.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  13.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  15.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   5.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  15.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  15.9s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   7.1s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   6.3s
# [CV] END bootstrap=True, class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   8.1s
# ...
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  13.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  13.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  13.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  14.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=  14.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  18.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  19.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  19.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  17.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  19.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   5.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   4.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  28.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  28.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  29.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  27.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  27.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  12.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  13.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  14.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  14.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  13.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  17.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  19.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  18.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   4.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  18.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   4.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   4.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   5.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   4.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  24.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  27.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   8.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  23.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  30.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  29.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  13.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  13.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  13.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  12.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  13.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  16.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  16.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  17.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  18.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  18.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   4.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   4.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   4.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   5.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  25.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   4.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  26.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  27.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   8.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   8.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  27.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   8.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  28.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  12.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  13.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  11.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  13.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  14.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  17.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  17.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  17.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   4.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  17.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  17.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   4.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   4.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   3.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   5.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  27.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  24.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  28.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.3s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  26.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  27.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.4s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  13.1s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  13.7s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  14.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  11.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  13.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  17.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  17.8s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  18.0s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  16.5s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  17.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  21.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  21.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  22.6s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  18.2s
# [CV] END bootstrap=False, class_weight=None, max_depth=40, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  19.6s
# Best hyperparameters found:  {'bootstrap': False, 'class_weight': None, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}

# %% [markdown]
# # Best Hyperparameter

# %%
best_params
# Out:
# {'bootstrap': False,
#  'class_weight': None,
#  'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %% [markdown]
# # Compare the defult with best hyper parameter

# %%
classifiers = {
    'RandomForest Default': RandomForestClassifier(random_state=42),
    'RandomForest Best Hyperparameters': RandomForestClassifier(
        bootstrap=False,
        class_weight=None,
        max_depth=None,
        min_samples_leaf=1,
        min_samples_split=2,
        n_estimators=300,
        random_state=42
    )
}
results_df = fit_and_evaluate_classifiers(classifiers,X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test, group=1)
# Out:
# Training RandomForest Default...
# Training RandomForest Best Hyperparameters...
#
# Performance Metrics:
#                           Classifier       AUC  Accuracy  Precision    Recall  \
# 0               RandomForest Default  0.890051  0.846259   0.670769  0.646884
# 1  RandomForest Best Hyperparameters  0.891981  0.853741   0.700658  0.632047
#
#    F1-Score
# 0  0.658610
# 1  0.664587
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[297], line 16
#      13 results_df = fit_and_evaluate_classifiers(classifiers,X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test, group=1)
#      15 # Call the function to fit classifiers and plot ROC curves
# ---> 16 fit_and_plot_roc_curve_multi_classifiers(classifiers,X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test)
#
# NameError: name 'fit_and_plot_roc_curve_multi_classifiers' is not defined

# %% [markdown]
# # Can the features output from RFECV rescue the model prediction
# Train the model only withese features
# Most Important Features (Rank 1): ['expected_combinatorial_lfc', 'Euclidean_distance_expexted_observed', 'highist_expression', 'lowest_expression', 'Euclidean_distance_expresstion', 'expre_Correlation', 'dep_Correlation', 'Jaccard BP Similarity', 'Jaccard MF Similarity', 'Average Wang BP Similarity', 'Average Wang MF Similarity', 'Average Wang CC Similarity', 'pscore', 'ascore', 'Jaccard Index_commun_proteins', 'Number of Common Proteins']

# %%
# split data with only these features

X_train, X_test, y_train, y_test = split_train_test(
    df=filtered_df,  
    target_col='temp_class_label',  
    exclude_cols=[
    'Class_label_sum', 'cell_line', 'condition', 'Gene_combination', 
    'Class_label_exp', 'Class_label_dep', 'Class_label_corr', 
    'Class_label_neg', 'temp_class_label', 'escore', 'score',
    'single_gene_highist_avg_lfc', 'single_gene_lowest_avg_lfc', 
    'combinatorial_avg_lfc', 'Euclidean_distance_singel_phenotype', 'highist_dep', 
    'lowest_dep', 'Euclidean_distance_dep', 'highist_damage_mutation', 
    'lowest_damage_mutation', 'Euclidean_distance_dm', 'nscore', 
    'fscore', 'dscore','Jaccard CC Similarity'
],
    group_by_cols=['Gene_combination'],  # Group by Gene_combination
    test_size=0.2,  # 20% of the data for testing
    random_state=42  # Set random state for reproducibility
)

# Get the column names of X_train
column_names = X_train.columns.tolist()
print(column_names)
# Out:
# Original label distribution: {0: 5690, 1: 1677}
# Training label distribution: {0: 4557, 1: 1340}
# Testing label distribution: {0: 1133, 1: 337}
# No biological replicate disruption across training and test sets.
# ['expected_combinatorial_lfc', 'Euclidean_distance_expexted_observed', 'highist_expression', 'lowest_expression', 'Euclidean_distance_expresstion', 'expre_Correlation', 'dep_Correlation', 'Jaccard BP Similarity', 'Jaccard MF Similarity', 'Average Wang BP Similarity', 'Average Wang MF Similarity', 'Average Wang CC Similarity', 'pscore', 'ascore', 'Jaccard Index_commun_proteins', 'Number of Common Proteins']

# %%
# Apply Tomek Links to clean training data
tomek = TomekLinks()
X_tomek, y_tomek = tomek.fit_resample(X_train, y_train)

# applay svmsmote to undersampling methods tomek
svmsmote = SVMSMOTE(sampling_strategy='minority',random_state = 42)
# fit the object to our training data
X_train_tomek_svmsmote, y_train_tomek_svmsmote= svmsmote.fit_resample(X_tomek, y_tomek)

# %% [markdown]
# # Plot the selected model classafier

# %%
classifiers = {
    'RandomForest Seleced Model': RandomForestClassifier(random_state=42),
    'DummyClassifier':DummyClassifier()
    }
results_df = fit_and_evaluate_classifiers(classifiers,X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test, group=1)

plot_custom_confusion_matrices_multi_classifiers(
    classifiers, 
    X_train_tomek_svmsmote, y_train_tomek_svmsmote, 
    X_test, y_test, 
    class_order=[1, 0],
    display_labels=['GI', 'No GI']  
)
# Call the function to fit classifiers and plot ROC curves
fit_and_plot_roc_curve_multi_classifiers(classifiers,X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test)
# Out:
# Training RandomForest Seleced Model...
# Training DummyClassifier...
#
# Performance Metrics:
#                    Classifier       AUC  Accuracy  Precision    Recall  \
# 0  RandomForest Seleced Model  0.890051  0.846259   0.670769  0.646884
# 1             DummyClassifier  0.500000  0.770748   0.000000  0.000000
#
#    F1-Score
# 0   0.65861
# 1   0.00000
# Training RandomForest Seleced Model...
# Training DummyClassifier...

# %% [markdown]
# # Extract positive predicted GI

# %%
def random_forest_extract(X_train, y_train, X_test, y_test, positive_class=1):
    """
    Train and evaluate a Random Forest classifier, and extract predictions for a specified class.
    
    Parameters:
    - X_train: Training features (DataFrame or array).
    - y_train: Training labels (Series or array).
    - X_test: Test features (DataFrame or array).
    - y_test: Test labels (Series or array).
    - positive_class: The class for which predictions are extracted (default is 1).

    Returns:
    - results_df: DataFrame containing True labels, Predicted labels, and class probabilities.
    - class_predictions: DataFrame containing samples predicted as the specified positive class.
    - classification_report_dict: Dictionary containing classification metrics.
    """
    # Step 1: Train the Random Forest model
    model = RandomForestClassifier(
    random_state=42)

    model.fit(X_train, y_train)

    # Step 2: Get predictions
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)

    # Step 3: Create a DataFrame to hold predictions and probabilities
    results_df = pd.DataFrame(X_test, columns=X_train.columns)  # Use original column names if available
    results_df['True_Label'] = y_test
    results_df['Predicted_Label'] = y_pred
    results_df[f'Probability_Class_{positive_class}'] = y_proba[:, positive_class]

    # Step 4: Filter for samples predicted as the positive class
    class_predictions = results_df[results_df['Predicted_Label'] == positive_class]

    # Step 5: Classification Report
    classification_report_dict = classification_report(y_test, y_pred, output_dict=True)

    # Print the classification report for overall performance
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Return the full results, class predictions for the positive class, and metrics
    return results_df, class_predictions, classification_report_dict

# %%
# Run the workflow
results_df, class_1_predictions, metrics = random_forest_extract(X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test, positive_class=1)

# Display samples predicted as class 1
print("\nSamples Predicted as Class 1:")
print(class_1_predictions)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90      1133
#            1       0.67      0.65      0.66       337
#
#     accuracy                           0.85      1470
#    macro avg       0.78      0.78      0.78      1470
# weighted avg       0.84      0.85      0.85      1470
#
#
# Samples Predicted as Class 1:
#       expected_combinatorial_lfc  Euclidean_distance_expexted_observed  \
# 57                     -4.441399                              1.673198
# 65                     -0.385859                              0.237022
# 93                     -1.759687                              1.134660
# 98                     -3.106985                              1.995113
# 186                    -0.280116                              0.994874
# ...                          ...                                   ...
# 7349                    0.143917                              0.047426
# 7361                    0.129944                              0.485685
# 7814                    0.307911                              0.295562
# 7888                   -0.080805                              0.260375
# 8341                   -0.453136                              0.485458
#
#       highist_expression  lowest_expression  Euclidean_distance_expresstion  \
# 57              6.969679           4.604295                        2.365385
# 65              3.173491           2.927887                        0.245605
# 93              3.620200           3.616954                        0.003246
# 98              2.851059           2.700505                        0.150554
# 186             3.833302           3.156348                        0.676954
# ...                  ...                ...                             ...
# 7349            1.864575           1.021953                        0.842622
# 7361            4.260311           2.455775                        1.804536
# 7814            2.312049           1.864575                        0.447474
# 7888            4.260311           1.864575                        2.395736
# 8341            2.994507           2.038642                        0.955865
#
#       expre_Correlation  dep_Correlation  Jaccard BP Similarity  \
# 57             0.087346         0.086616               0.312500
# 65             0.176581         0.074694               0.127660
# 93             0.402737         0.102465               0.300000
# 98             0.336011         0.154745               0.450000
# 186            0.300492        -0.034947               0.227273
# ...                 ...              ...                    ...
# 7349           0.461583         0.043895               0.250000
# 7361           0.591582        -0.051843               0.200000
# 7814           0.400896         0.047057               0.500000
# 7888           0.762634         0.096384               0.500000
# 8341           0.754219         0.354384               1.000000
#
#       Jaccard MF Similarity  Average Wang BP Similarity  \
# 57                 0.545455                    0.183500
# 65                 0.631579                    0.160420
# 93                 0.428571                    0.232579
# 98                 0.666667                    0.207903
# 186                0.222222                    0.186173
# ...                     ...                         ...
# 7349               0.625000                    0.752036
# 7361               0.625000                    0.589533
# 7814               0.714286                    0.817876
# 7888               0.500000                    0.564026
# 8341               1.000000                    0.968207
#
#       Average Wang MF Similarity  Average Wang CC Similarity  pscore  ascore  \
# 57                      0.368244                    0.413325   0.000   0.000
# 65                      0.327149                    0.361737   0.055   0.049
# 93                      0.402916                    0.338312   0.049   0.092
# 98                      0.456523                    0.360135   0.050   0.059
# 186                     0.486463                    0.407433   0.056   0.000
# ...                          ...                         ...     ...     ...
# 7349                    0.372289                    0.443689   0.061   0.060
# 7361                    0.369480                    0.660821   0.000   0.000
# 7814                    0.358918                    0.465472   0.064   0.055
# 7888                    0.348974                    0.443689   0.080   0.096
# 8341                    0.390245                    1.000000   0.000   0.000
#
#       Jaccard Index_commun_proteins  Number of Common Proteins  True_Label  \
# 57                         0.428571                          6           0
# 65                         0.176471                          3           0
# 93                         0.333333                          5           0
# 98                         0.666667                          8           1
# 186                        0.176471                          3           0
# ...                             ...                        ...         ...
# 7349                       0.250000                          4           1
# 7361                       0.428571                          6           0
# 7814                       0.428571                          6           1
# 7888                       0.250000                          4           1
# 8341                       0.076923                          1           1
#
#       Predicted_Label  Probability_Class_1
# 57                  1                 0.78
# 65                  1                 0.62
# 93                  1                 0.75
# 98                  1                 0.89
# 186                 1                 0.86
# ...               ...                  ...
# 7349                1                 0.80
# 7361                1                 0.66
# 7814                1                 0.81
# 7888                1                 0.77
# 8341                1                 0.79
#
# [325 rows x 19 columns]

# %% [markdown]
# # Class 1 positive prediction

# %%
# Merge the DataFrames based on common columns
common_columns = ['expected_combinatorial_lfc', 'Euclidean_distance_expexted_observed', 'highist_expression', 'lowest_expression', 'Euclidean_distance_expresstion', 'expre_Correlation', 'dep_Correlation', 'Jaccard BP Similarity', 'Jaccard MF Similarity', 'Average Wang BP Similarity', 'Average Wang MF Similarity', 'Average Wang CC Similarity', 'pscore', 'ascore', 'Jaccard Index_commun_proteins', 'Number of Common Proteins']


merged_df_positives = class_1_predictions.merge(
    filtered_df[['Class_label_sum','Class_label_exp', 'Class_label_dep','Class_label_corr','cell_line', 'condition', 'Gene_combination'] + common_columns],
    on=common_columns, how='left'
)
merged_df_positives
# Out:
#      expected_combinatorial_lfc  Euclidean_distance_expexted_observed  \
# 0                     -4.441399                              1.673198
# 1                     -0.385859                              0.237022
# 2                     -1.759687                              1.134660
# 3                     -3.106985                              1.995113
# 4                     -0.280116                              0.994874
# ..                          ...                                   ...
# 320                    0.143917                              0.047426
# 321                    0.129944                              0.485685
# 322                    0.307911                              0.295562
# 323                   -0.080805                              0.260375
# 324                   -0.453136                              0.485458
#
#      highist_expression  lowest_expression  Euclidean_distance_expresstion  \
# 0              6.969679           4.604295                        2.365385
# 1              3.173491           2.927887                        0.245605
# 2              3.620200           3.616954                        0.003246
# 3              2.851059           2.700505                        0.150554
# 4              3.833302           3.156348                        0.676954
# ..                  ...                ...                             ...
# 320            1.864575           1.021953                        0.842622
# 321            4.260311           2.455775                        1.804536
# 322            2.312049           1.864575                        0.447474
# 323            4.260311           1.864575                        2.395736
# 324            2.994507           2.038642                        0.955865
#
#      expre_Correlation  dep_Correlation  Jaccard BP Similarity  \
# 0             0.087346         0.086616               0.312500
# 1             0.176581         0.074694               0.127660
# 2             0.402737         0.102465               0.300000
# 3             0.336011         0.154745               0.450000
# 4             0.300492        -0.034947               0.227273
# ..                 ...              ...                    ...
# 320           0.461583         0.043895               0.250000
# 321           0.591582        -0.051843               0.200000
# 322           0.400896         0.047057               0.500000
# 323           0.762634         0.096384               0.500000
# 324           0.754219         0.354384               1.000000
#
#      Jaccard MF Similarity  Average Wang BP Similarity  ...  True_Label  \
# 0                 0.545455                    0.183500  ...           0
# 1                 0.631579                    0.160420  ...           0
# 2                 0.428571                    0.232579  ...           0
# 3                 0.666667                    0.207903  ...           1
# 4                 0.222222                    0.186173  ...           0
# ..                     ...                         ...  ...         ...
# 320               0.625000                    0.752036  ...           1
# 321               0.625000                    0.589533  ...           0
# 322               0.714286                    0.817876  ...           1
# 323               0.500000                    0.564026  ...           1
# 324               1.000000                    0.968207  ...           1
#
#      Predicted_Label  Probability_Class_1  Class_label_sum  Class_label_exp  \
# 0                  1                 0.78            no GI            no GI
# 1                  1                 0.62            no GI            no GI
# 2                  1                 0.75            no GI            no GI
# 3                  1                 0.89            no GI               GI
# 4                  1                 0.86            no GI            no GI
# ..               ...                  ...              ...              ...
# 320                1                 0.80            no GI               GI
# 321                1                 0.66            no GI            no GI
# 322                1                 0.81            no GI               GI
# 323                1                 0.77            no GI               GI
# 324                1                 0.79            no GI               GI
#
#      Class_label_dep  Class_label_corr  cell_line  condition Gene_combination
# 0              no GI             no GI       A375        2CP      ACSL3_ACSL4
# 1              no GI             no GI       A375        2CP    ACVR1B_TGFBR1
# 2              no GI             no GI       A375        2CP        AGO1_AGO2
# 3              no GI             no GI       A375        2CP        AGO3_AGO4
# 4              no GI             no GI       A375        2CP      APBB1_APBB2
# ..               ...               ...        ...        ...              ...
# 320            no GI             no GI    Meljuso    2CP sel   ZKSCAN4_ZNF397
# 321            no GI             no GI    Meljuso    2CP sel    ZKSCAN8_ZNF24
# 322            no GI             no GI    Meljuso    2CP sel    ZNF232_ZNF397
# 323            no GI                GI    Meljuso    2CP sel     ZNF24_ZNF397
# 324               GI                GI    Meljuso    2CP sel    ZNF417_ZNF587
#
# [325 rows x 26 columns]

# %%
merged_df_positives
# Sort the DataFrame by the 'Score' column in descending order
df_sorted = merged_df_positives.sort_values(by='Probability_Class_1', ascending=False)
df_sorted
# Out:
#      expected_combinatorial_lfc  Euclidean_distance_expexted_observed  \
# 261                   -0.619848                              0.437799
# 108                   -8.764912                              5.108812
# 270                   -6.737109                              4.082036
# 251                   -1.320289                              0.255877
# 41                    -1.432005                              0.319133
# ..                          ...                                   ...
# 55                    -3.497061                              1.347122
# 300                    0.052012                              0.009240
# 37                     0.453856                              0.933113
# 16                    -0.117638                              0.474846
# 38                     0.518467                              0.689041
#
#      highist_expression  lowest_expression  Euclidean_distance_expresstion  \
# 261            7.426641           6.367170                        1.059471
# 108            7.919391           6.596557                        1.322834
# 270            7.605290           6.600122                        1.005169
# 251            4.925937           3.950378                        0.975559
# 41             6.663721           5.433590                        1.230131
# ..                  ...                ...                             ...
# 55             6.447566           4.836692                        1.610874
# 300            8.551628           0.884382                        7.667246
# 37             5.598699           3.524508                        2.074192
# 16             4.986099           0.583264                        4.402835
# 38             5.988417           3.258959                        2.729458
#
#      expre_Correlation  dep_Correlation  Jaccard BP Similarity  \
# 261           0.149144         0.029649               0.384615
# 108           0.334410         0.261920               0.285714
# 270           0.334410         0.261920               0.285714
# 251           0.662843         0.336673               0.777778
# 41            0.298219         0.191365               0.321429
# ..                 ...              ...                    ...
# 55            0.459975         0.019399               0.333333
# 300           0.186884         0.000490               0.333333
# 37            0.485452         0.706943               0.071429
# 16            0.570729         0.140022               0.324324
# 38            0.156809         0.011739               0.125000
#
#      Jaccard MF Similarity  Average Wang BP Similarity  ...  True_Label  \
# 261               0.642857                    0.302554  ...           1
# 108               0.666667                    0.219515  ...           1
# 270               0.666667                    0.219515  ...           1
# 251               0.666667                    0.451522  ...           1
# 41                0.615385                    0.206067  ...           0
# ..                     ...                         ...  ...         ...
# 55                0.400000                    0.308020  ...           0
# 300               0.250000                    0.385662  ...           0
# 37                0.384615                    0.093600  ...           1
# 16                0.333333                    0.163484  ...           0
# 38                0.384615                    0.164087  ...           0
#
#      Predicted_Label  Probability_Class_1  Class_label_sum  Class_label_exp  \
# 261                1                 0.99            no GI               GI
# 108                1                 0.99              lol               GI
# 270                1                 0.99              lol               GI
# 251                1                 0.98            no GI               GI
# 41                 1                 0.97            no GI            no GI
# ..               ...                  ...              ...              ...
# 55                 1                 0.51            no GI            no GI
# 300                1                 0.51            no GI            no GI
# 37                 1                 0.51            no GI               GI
# 16                 1                 0.51            no GI            no GI
# 38                 1                 0.51            no GI            no GI
#
#      Class_label_dep  Class_label_corr  cell_line  condition Gene_combination
# 261            no GI             no GI    Meljuso    2CP sel        PFKM_PFKP
# 108               GI             no GI       A375        2CP      PSMC4_PSMC6
# 270               GI             no GI    Meljuso    2CP sel      PSMC4_PSMC6
# 251               GI                GI    Meljuso    2CP sel        NFIC_NFIX
# 41             no GI             no GI       A375        2CP        FXR1_FXR2
# ..               ...               ...        ...        ...              ...
# 55             no GI             no GI       A375        2CP        IPO7_IPO8
# 300            no GI             no GI    Meljuso    2CP sel     TAGLN_TAGLN2
# 37                GI             no GI       A375        2CP       EXT2_EXTL3
# 16             no GI             no GI       A375        2CP      CASP1_CASP4
# 38             no GI             no GI       A375        2CP      FKBP4_FKBP5
#
# [325 rows x 26 columns]

# %% [markdown]
# # Write sorted to file

# %%
df_sorted.to_csv('GI_prediction_expremint_label_final.csv', index=False)

# %%
results_df

# Merge the DataFrames based on common columns
common_columns = ['expected_combinatorial_lfc', 'Euclidean_distance_expexted_observed', 'highist_expression', 'lowest_expression', 'Euclidean_distance_expresstion', 'expre_Correlation', 'dep_Correlation', 'Jaccard BP Similarity', 'Jaccard MF Similarity', 'Average Wang BP Similarity', 'Average Wang MF Similarity', 'Average Wang CC Similarity', 'pscore', 'ascore', 'Jaccard Index_commun_proteins', 'Number of Common Proteins']


merged_df_whole = results_df.merge(
    filtered_df[['Class_label_sum','Class_label_exp', 'Class_label_dep','Class_label_corr','cell_line', 'condition', 'Gene_combination'] + common_columns],
    on=common_columns, how='left'
)
merged_df_whole

merged_df_whole.to_csv('Test_set_expremint_label_final.csv', index=False)

# %% [markdown]
# # Testing using only pscore and score

# %%
# split data with only these features

X_train, X_test, y_train, y_test = split_train_test(
    df=filtered_df,  
    target_col='temp_class_label',  
 exclude_cols = [
    'Class_label_sum', 'cell_line', 'condition', 'Gene_combination', 
    'Class_label_exp', 'Class_label_dep', 'Class_label_corr', 
    'Class_label_neg', 'temp_class_label', 'escore', 'score',
    'single_gene_highist_avg_lfc', 'single_gene_lowest_avg_lfc', 
    'combinatorial_avg_lfc', 'Euclidean_distance_singel_phenotype', 'highist_dep', 
    'lowest_dep', 'Euclidean_distance_dep', 'highist_damage_mutation', 
    'lowest_damage_mutation', 'Euclidean_distance_dm', 'nscore', 
    'fscore', 'dscore', 'Jaccard CC Similarity',  
    'expected_combinatorial_lfc', 'highist_expression', 'lowest_expression', 
    'Euclidean_distance_expresstion', 'dep_Correlation', 'Jaccard BP Similarity', 
    'Jaccard MF Similarity', 'Average Wang MF Similarity', 
    'Average Wang CC Similarity', 'Jaccard Index_commun_proteins','Number of Common Proteins',
    'Euclidean_distance_expexted_observed', 'expre_Correlation', 'Average Wang BP Similarity',
    
],

    group_by_cols=['Gene_combination'],  # Group by Gene_combination
    test_size=0.2,  # 20% of the data for testing
    random_state=42  # Set random state for reproducibility
)

# Get the column names of X_train
column_names = X_train.columns.tolist()
print(column_names)
# Out:
# Original label distribution: {0: 5690, 1: 1677}
# Training label distribution: {0: 4557, 1: 1340}
# Testing label distribution: {0: 1133, 1: 337}
# No biological replicate disruption across training and test sets.
# ['pscore', 'ascore']

# %%
# Apply Tomek Links to clean training data
tomek = TomekLinks()
X_tomek, y_tomek = tomek.fit_resample(X_train, y_train)

# applay svmsmote to undersampling methods tomek
svmsmote = SVMSMOTE(sampling_strategy='minority',random_state = 42)
# fit the object to our training data
X_train_tomek_svmsmote, y_train_tomek_svmsmote= svmsmote.fit_resample(X_tomek, y_tomek)

# %%
classifiers = {
    'pscore, ascore': RandomForestClassifier(random_state=42),
}
results_df = fit_and_evaluate_classifiers(classifiers,X_train_tomek_svmsmote, y_train_tomek_svmsmote, X_test, y_test, group=1)

plot_custom_confusion_matrices_multi_classifiers(
    classifiers, 
    X_train_tomek_svmsmote, y_train_tomek_svmsmote, 
    X_test, y_test, 
    class_order=[1, 0],
    display_labels=['GI', 'No GI']  
)
# Out:
# Training pscore, ascore...
#
# Performance Metrics:
#        Classifier      AUC  Accuracy  Precision    Recall  F1-Score
# 0  pscore, ascore  0.68315  0.838095   0.753846  0.436202  0.552632
# Training pscore, ascore...
